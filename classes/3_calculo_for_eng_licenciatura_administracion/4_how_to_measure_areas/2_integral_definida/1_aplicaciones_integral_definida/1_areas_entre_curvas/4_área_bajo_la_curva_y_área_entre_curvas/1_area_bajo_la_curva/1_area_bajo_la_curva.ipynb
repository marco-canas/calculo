# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/1_areas_entre_curvas/4_%C3%A1rea_bajo_la_curva_y_%C3%A1rea_entre_curvas/1_area_bajo_la_curva/1_area_bajo_la_curva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/1_areas_entre_curvas/4_%C3%A1rea_bajo_la_curva_y_%C3%A1rea_entre_curvas/1_area_bajo_la_curva/1_area_bajo_la_curva.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental ](https://www.youtube.com/watch?v=dqeyUYWEq5I)

# %% [markdown]
# ## [Vínculo al programa del curso:](https://github.com/marco-canas/calculo/blob/main/programas_de_curso/2_programa_calculo_Integral_ingenieria_agropecuaria.docx)

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'
estudiantes = pd.read_csv(path)

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def asistencia():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Asistió {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.01
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    asistencia()

guardar_cambios()
# Out:
# Llamando a GUERRA NORIEGA YONATHAN...
# Llamando a CANTILLO ENSUCHO DANIEL...
# Actualizado: CANTILLO ENSUCHO DANIEL ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a CERVANTES DURAN ANGELICA...
# Actualizado: CERVANTES DURAN ANGELICA ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a QUINONEZ CERVANTES MARIANA...
# Actualizado: QUINONEZ CERVANTES MARIANA ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a RIVAS HOYOS ESTEFANIA...
# Actualizado: RIVAS HOYOS ESTEFANIA ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a AMARIS FERNANDEZ SEBASTIAN CAMILO...
# Llamando a MONTERROSA SOTO ABRIL...
# Actualizado: MONTERROSA SOTO ABRIL ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a PEREZ THERAN ERLINDA...
# Actualizado: PEREZ THERAN ERLINDA ahora tiene 0.01 en la columna 'Parcial'.
# Llamando a PINEDA ROMERO YOSMERI...
# Llamando a HINCAPIE CASTRO JOHAN SEBASTIAN...
# Actualizado: HINCAPIE CASTRO JOHAN SEBASTIAN ahora tiene 0.01 en la columna 'Parcial'.
# ...

# %%
# Out:
# Llamando a ROSILLO TEJADA VANESA...

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/calculo/blob/main/images/student_images/alegria_femenina_2023-11-17.jpeg?raw=true'>

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# ![Definamos flipped learning de manera gráfica](https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png)

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# [Encuentra tu persona vitamina](https://github.com/marco-canas/encuentra_tu_persona_vitamina/blob/main/14_el_placer/14_1_no_me_se_su_nombre_solo_he_tenido_sexo_con_el/1_14_1_el_placer_no_me_se_su_nombre_solo_he_tenido_sexo_con_el.ipynb)

# %% [markdown]
# ## Título de la clase: Aplicaciones de la integración definida al cálculo de áreas de regiones no poligonales

# %%
# ejemplo de una región que no sea poligonal
import matplotlib.pyplot as plt 
import numpy as np 

dominio = np.arange(start = -1, stop = 1, step = 0.001) # la función arange es una experta en crear progresiones aritméticas 
def semicircunferencia(x):
    return np.sqrt(1-x**2)
rango = semicircunferencia(dominio)
plt.title('Gráfica de una superficie o región no poligonal') 
plt.plot(dominio, rango, 'r-')
plt.fill_between(dominio, rango)
plt.axis('equal')
plt.grid(True)

plt.savefig('/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_area/semicirculo.jpg')

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Recordar cómo clasificar los triángulos y cómo determinar su área.
# * Recordar cómo clasificar los cuadriláteros y cómo determinar su área.
# * Presentar la integral definida como el límite de una suma de áreas de rectángulos inscritos en una región.
# * Determinar el área de regiones no triangulares y no cuadrangulares utilizando el concepto de integración definida:
#
# $$ \text{Área} = \int_{a}^{b} f(x) \ dx  $$

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# Aquí tienes un cuestionario de presaberes para la clase sobre aplicaciones de la integral definida:
#
# **Cuestionario de Presaberes: Aplicaciones de la Integral Definida**
#
# 1. ¿Cómo se clasifican los triángulos según la medida de sus lados?
#    a) Equiláteros, isósceles, escalenos
#    b) Acutángulos, obtusángulos, rectángulos
#    c) Agudos, obtusos, rectos
#    Respuesta correcta: a) Equiláteros, isósceles, escalenos

# %% [markdown]
# 2. ¿Cuál es la fórmula para calcular el área de un triángulo?
#    a) `Area = 1/2 * base * altura`
#    b) A = base * altura
#    c) A = lado^2
#    Respuesta correcta: a) A = 1/2 * base * altura

# %% [markdown]
# 3. ¿Cómo se clasifican los cuadriláteros según la forma de sus lados?
#    a) Cuadrados, rectángulos, rombos, trapecios
#    b) Cuadrados, rombos, trapecios, pentágonos
#    c) Triángulos, cuadriláteros, pentágonos, hexágonos
#    Respuesta correcta: a) Cuadrados, rectángulos, rombos, trapecios

# %% [markdown]
# 4. ¿Cuál es la fórmula para calcular el área de un cuadrilátero?
#    a) A = base * altura
#    b) A = lado^2
#    c) Depende del tipo de cuadrilátero
#    Respuesta correcta: c) Depende del tipo de cuadrilátero

# %% [markdown]
# 5. ¿Cómo se define la integral definida?
#    a) Como la suma de las áreas de rectángulos inscritos en una región
#    b) Como el límite de una suma de áreas de rectángulos inscritos en una región
#    c) Como la diferencia entre las áreas de rectángulos inscritos y circunscritos en una región
#    Respuesta correcta: b) Como el límite de una suma de áreas de rectángulos inscritos en una región

# %% [markdown]
# 6. ¿Qué representa la expresión $$ \int_{a}^{b} f(x) \ dx $$ en el contexto de la integral definida?
#    a) El área bajo la curva de la función $f(x)$ en el intervalo \([a, b]\)
#    b) El límite de una suma de áreas de rectángulos inscritos en una región
#    c) La longitud de la curva $f(x)$ en el intervalo $[a, b]$
#    Respuesta correcta: a) El área bajo la curva de la función $ f(x) $ en el intervalo $[a, b] $
#
# Espero que este cuestionario sea útil para evaluar los presaberes de tus estudiantes.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.

# %% [markdown]
# Aquí tienes una lista de prerrequisitos conceptuales para la clase sobre aplicaciones de la integral definida:

# %% [markdown]
# 1. Comprensión de los conceptos básicos de geometría, incluyendo la clasificación de triángulos y cuadriláteros, así como el cálculo de áreas.
# 2. Conocimiento de funciones y cómo interpretarlas gráficamente.
# 3. Entendimiento de la definición de integral definida y su relación con el cálculo de áreas bajo una curva.
# 4. Familiaridad con los conceptos de límites y sumas de Riemann, ya que la integral definida se define como el límite de una suma de áreas de rectángulos inscritos en una región.
# 5. Conocimiento básico de álgebra y trigonometría, especialmente en el contexto de funciones.
# 6. Familiaridad con el uso de notación matemática, incluyendo la comprensión de símbolos como \( \int \) y \( dx \) en el contexto de la integral definida.

# %% [markdown]
# Estos prerrequisitos conceptuales son importantes para que los estudiantes puedan comprender y aplicar adecuadamente los conceptos relacionados con las aplicaciones de la integral definida en la clase.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje
#
# Aquí tienes una lista de posibles problemas de aprendizaje para la clase sobre aplicaciones de la integral definida, junto con algunas estrategias para abordarlos:

# %% [markdown]
# 1. El cuadrado de una décima es una centésima: Problemas para calcular el cuadrado de un decimal.
# 2. El cuadrado de un cociente es el cociente de los cuadrados.
# 3. Alinear los iguales.
# 4. Dificultad de aplicación del teorema fundamental del cálculo.
# 5. Elevar al cuadrado no es multiplicar por 2

# %% [markdown]
# 1. **Falta de comprensión de los conceptos básicos de geometría:** Algunos estudiantes pueden tener dificultades para clasificar triángulos y cuadriláteros, así como para calcular áreas.
#    - Estrategia: Repasar brevemente los conceptos básicos de geometría al principio de la clase y proporcionar ejemplos prácticos para reforzar el aprendizaje.

# %% [markdown]
# 2. **Dificultad para comprender la relación entre la integral definida y el cálculo de áreas:** Algunos estudiantes pueden tener dificultades para entender cómo la integral definida se relaciona con el cálculo de áreas bajo una curva.
#    - Estrategia: Utilizar ejemplos visuales y prácticos para ilustrar cómo la integral definida representa el área bajo una curva. Proporcionar ejercicios guiados para que los estudiantes practiquen calcular áreas utilizando la integral definida.

# %% [markdown]
# 3. **Problemas para aplicar la integral definida en el cálculo de áreas de regiones no triangulares y no cuadrangulares:** Algunos estudiantes pueden encontrar difícil aplicar la integral definida para determinar el área de regiones con formas irregulares.
#    - Estrategia: Proporcionar una variedad de ejemplos que cubran diferentes tipos de regiones, incluyendo polígonos no regulares y curvas. Guiar a los estudiantes a través del proceso paso a paso y proporcionar retroalimentación inmediata sobre su trabajo.

# %% [markdown]
# 4. **Confusión con la notación matemática y los símbolos utilizados en la integral definida:** Algunos estudiantes pueden tener dificultades para entender la notación matemática utilizada en la integral definida.
#    - Estrategia: Explicar claramente la notación matemática utilizada en la integral definida y proporcionar ejemplos de su aplicación en contextos reales. Animar a los estudiantes a practicar la escritura y manipulación de expresiones matemáticas para mejorar su comprensión.
#
# Al abordar estos posibles problemas de aprendizaje y aplicar estas estrategias, los estudiantes podrán desarrollar una comprensión más sólida de las aplicaciones de la integral definida y mejorar su capacidad para resolver problemas relacionados con el cálculo de áreas.

# %% [markdown]
# 5. Diferenciar entre semicircunferencia superior y parábola que abre hacia abajo.
#
# Les agregaré una animación con matplotlib de una comparación en el lado izquierdo de una semicircunferencia y al lado derecho de una parábola que abre hacia abajo.

# %% [markdown]
# # La integral definida aplicada al cálculo de áreas
#
# ## Secuencia conceptual introductoria a la clase
#
# ### El componente histórico y epistemológico  sobre la integral definida como él area bajo la curva de una función continua en un intervalo $[a,b]$

# %% [markdown]
# Aquí tienes algunos elementos históricos y epistemológicos relevantes para la clase sobre aplicaciones de la integral definida:

# %% [markdown]
# 1. **Orígenes del cálculo integral:** El cálculo integral tiene sus raíces en el trabajo de matemáticos antiguos como Arquímedes, quien desarrolló métodos para calcular áreas y volúmenes mediante la aproximación de figuras con polígonos. Sin embargo, el formalismo moderno del cálculo integral se desarrolló principalmente en el siglo XVII, con contribuciones clave de matemáticos como Isaac Newton y Gottfried Wilhelm Leibniz.

# %% [markdown]
# 2. **Desarrollo del concepto de área bajo una curva:** Durante el Renacimiento y la Era de la Ilustración, los matemáticos comenzaron a investigar el área bajo una curva como un problema matemático fundamental. Este trabajo culminó en la formulación del teorema fundamental del cálculo, que establece la relación entre la integral definida y la derivada de una función.
#
# 3. **Aplicaciones en la física y la ingeniería:** El cálculo integral ha demostrado ser una herramienta poderosa en la resolución de problemas en física y ingeniería. Desde el cálculo de áreas y volúmenes hasta la determinación de centros de masa y momentos de inercia, las aplicaciones prácticas del cálculo integral son numerosas y diversas.
#
# 4. **Avances en la teoría matemática:** A lo largo de los siglos XIX y XX, el cálculo integral experimentó un desarrollo significativo con la formulación de nuevas teorías y métodos. La teoría de la medida y la integración de Lebesgue, por ejemplo, extendió el alcance del cálculo integral y proporcionó una base más sólida para el análisis matemático moderno.
#
# 5. **Epistemología del cálculo integral:** La comprensión del cálculo integral implica la apreciación de conceptos fundamentales como límites, infinitesimales y la relación entre cambio y acumulación. Estos conceptos tienen implicaciones filosóficas profundas en nuestra comprensión de la naturaleza del cambio y la continuidad en el mundo físico y matemático.

# %% [markdown]
# Al explorar estos elementos históricos y epistemológicos, los estudiantes pueden adquirir una comprensión más profunda y contextualizada de las aplicaciones de la integral definida y su importancia en diversos campos del conocimiento.

# %% [markdown]
# ## Agenda de la clase
# 1. Tomar a lista
# 2. [Normas de convevencia](https://github.com/marco-canas/groups_list/blob/main/limites_para_servir.docx)
# 3. [Programa del curso.](https://github.com/marco-canas/calculo/blob/main/programas_de_curso/2_programa_calculo_Integral_ingenieria_agropecuaria.docx)
# 4. Recordar Clasificación de los triángulos y determinación del área de ellos.
# 2. Recordar Clasificación de los cuadriláteros y determinación del área de ellos.
# 3. Recorderis algunas fórmulas de integración indefinida que hemos considerado necesarias para aplicaciones a la ingeniería agropecuaria. Se le pidió  a los estudiantes que las debe memorizar, saber interpretar y saber aplicar.
# 4. Aprender a trazar a mano regiones en el plano no poligonales.
# 5. Determinación de áreas de regiones **no poligonales utilizando Integración definida**.
# 6. [Estimar el área del Campus Caucasia de la Universidad de Antioquia](https://play.google.com/store/apps/details?id=com.gaurgrow.distancelandareameasure&pli=1&raii=com.gaurgrow.distancelandareameasure&rapt=AEjHL4MLX09BGW4IsbjVorKq3iWFCNr4lGyr6f7cQD9DYhH4nV3meZlymdtDrWxCU9MJfpI5QGD2Pf5gDaHSyB2E6L6Yn24C8CCjgBOLKWxi1VoFQfmB0BNCwAj_Cve-WVJ8-1KnDBiQ)

# %% [markdown]
# # Elementos o partes de los triángulos y su notación
#
# 1. Vértices: $\{A, B, C \}$
# 2. Ańgulos: $\{\angle A = \hat{A}, \angle B = \hat{B}, \angle C = \hat{C} \}$
# 3. lados: $\{ \bar{AB}, \bar{AC}, \bar{BC} \}$
# 4. ángulo opuesto a un lado:
# 5. qué es lado opuesto a un ángulo de un triángulo.

# %%
import numpy as np 
import matplotlib.pyplot as plt
A, B, C = (0,0), (3,0), (2,1)
x_coords, y_coords = zip(A,B,C,A)
plt.plot(x_coords, y_coords)
plt.grid(alpha = 0.3)
plt.text(A[0]-0.1, A[1], 'A')
plt.text(B[0]+ 0.05, B[1], 'B')
plt.text(C[0]-0.1, C[1], 'C')
plt.axis('off')
# Out:
# (-0.15000000000000002, 3.15, -0.05, 1.05)

# %% [markdown]
# # Clasificación de los triángulos y área de ellos

# %%
# mapa conceptual de clasificación de los triángulos
from graphviz import Digraph

# Crear un nuevo grafo dirigido
dot = Digraph()

# Añadir nodos y relaciones al grafo
main_concept = 'Clasificación de los triángulos'
dot.node('A', main_concept)
dot.node('B', 'Criterio de la medida de los ángulos')
dot.node('C', 'Criterio de la medida de los lados')
dot.node('D', 'Trángulos Acutángulo')
dot.node('E', 'Trángulos Equiángulo')
dot.node('F', 'Trángulos rectángulos')
dot.node('G', 'Trángulos obtusángulos')

dot.node('H', 'Triángulos equiláteros')
dot.node('I', 'Triángulos isósceles')
dot.node('J', 'Triángulos escalenos')

dot.edges(['AB', 'AC'])
dot.edges(['BD', 'BF', 'BG'])
dot.edges(['CI', 'CJ'])
dot.edges(['DE', 'IH'])


# Guardar el grafo como un archivo de imagen
dot.render(filename=main_concept, format='png', cleanup=True, \
           directory='/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_areas')

dot.view()
# Out:
# '/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_areas/Clasificación de los triángulos.pdf'

# %% [markdown]
# [Video de apoyo a la lectura del mapa conceptual](https://www.youtube.com/watch?v=8mzLPXt1Knk)

# %% [markdown]
# # Cómo determinar áreas de los triángulos
#
# ## Metodología para determinar el área de un triángulo general
#
# 1. Elige un lado como base para la determinación del área.
# 2. Determina la altura relativa a la base elegida.
# 3. Efectuá el semiproducto de la base elegida y la altura determinada.

# %% [markdown]
# ## Segundo método para determinar áreas de triángulos: La fórmula de Herón de Alejandría
#
# $$ \text{Área del triángulo} = \sqrt{s(s-a)(s-b)(s-c)} $$

# %% [markdown]
# # Elementos de un cuadrilátero y su notación
#
# 1. Vértices: $\{A, B, C, D\}$
# 2. Ángulos: $\{\angle A, \}$
# 3. Lados:
# 4. Ládos consecutivos o adyacentes:
# 5. Lados opuestos:

# %% [markdown]
# # Clasificación de los cuadriláteros

# %%
# mapa conceptual de clasificación de los triángulos
from graphviz import Digraph

# Crear un nuevo grafo dirigido
dot = Digraph()

# Añadir nodos y relaciones al grafo
main_concept = 'Clasificación de los Cuadriláteros'
dot.node('A', main_concept)
dot.node('B', 'Criterio de paralelismo de los lados opuestos')
dot.node('C', 'Criterio de la medida de los lados para cuadriláteros')
dot.node('D', 'Criterio de la medida de los ángulos para cuadriláteros')
dot.node('E', 'Trapecios')
dot.node('F', 'Paralelogramos')
dot.node('G', 'Rombos')
dot.node('H', 'Rectángulos')
dot.node('I', 'Cuadrados')


dot.edges(['AB', 'AC', 'AD'])
dot.edges(['BE', 'EF', 'FG', 'FH', 'GI', 'HI'])

# Guardar el grafo como un archivo de imagen
dot.render(filename=main_concept, format='png', cleanup=True, \
           directory='/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_areas')

dot.view()
# Out:
# '/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_areas/Clasificación de los Cuadriláteros.pdf'

# %% [markdown]
# # Cómo determinar áreas de cuadriláteros

# %% [markdown]
# 1. El área de un rectángulo es el producto de dos de sus lados consecutivos.
# 2. El área de un trapecio es.
# 3. El área de un paralelogramo es .

# %% [markdown]
# # Videos cortos para ayudar al aprendizaje
#
# 1. Clasificación de triángulos y determinación de áreas de ellos.
#    [Video sólo para triángulos]()
# 2. Clasificación de cuadriláteros y determinación del área de ellos.
#    [Video sólo para cuadriláteros]()
# 3. Áres de regiones no triangulares y no cuadrangulares.
#    [Un video que valla al grano]()

# %% [markdown]
# # Fórmulas de integración
#
# 1. La regla de la potencia: $$ \int x^{n} = \frac{x^{n+1}}{n+1}  + C$$
# 2. La integral de una constante: $$ \int k \ dx = kx + C $$
# 3. La integral de un múltiplo constante de una función $f$
#    $$\int kf \ dx = k \int f(x) \ dx$$
# 4. La integral de una suma de funciones::
#
# $$ \int f + g = \int f + \in g $$
#
#
# 5. La integral de la función exponencial:
#
#    $$\int e^{x} dx = e^{x} + C$$
#
# 6. La integral de la función recíproca:
#    $$ \int \frac{1}{x} = \ln |x| + C  $$
#
#    Aprendase estas fórmulas de memoria.

# %% [markdown]
# # Aprender a trazar regiones no poligonales del cálculo
#
# 1. Aprender a trazar curvas a mano o de manera manuscrita
# 2. Aprender a trazar regiones no poligonales con matplotlib.

# %% [markdown]
# ### Ejemplo de trazado a mano de una región no poligonal
#
# Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^{2} + 1$, $x = -1$, $x = 2$ y el eje $x$.
#
# #### Metodología para trazar una región a mano:
#
# 1. traza el gráfico de la función con el método de trazado de puntos
# 2. traza las rectas verticales
# 3. resalta el eje x que acota por debajo a la región bajo la curva.

# %% [markdown]
# ### Ejemplo de trazado con matplotlib de una región no poligonal

# %% [markdown]
# # Tarea 1 de ejercitación y adquisiciión de habilidades para trazar a mano regiones bajo la curva de una función.

# %% [markdown]
# ### Ejercicios de trazado a mano de una región no poligonal
#
# 1. **Función Lineal**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = 2x + 3$, $x = -2$, $x = 1$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 2. **Función Cuadrática**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = -x^{2} + 4$, $x = -2$, $x = 2$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 3. **Función Polinomial**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^{3} - 3x + 2$, $x = -2$, $x = 1$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 4. **Función Racional**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \frac{2}{x}$, $x = 1$, $x = 3$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 5. **Función Exponencial**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = e^{x}$, $x = -1$, $x = 1$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 6. **Función Logarítmica**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \ln(x)$, $x = 1$, $x = 4$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 7. **Función Trigonométrica (Seno)**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \sin(x)$, $x = 0$, $x = \pi$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 8. **Función Trigonométrica (Coseno)**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \cos(x)$, $x = -\frac{\pi}{2}$, $x = \frac{\pi}{2}$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 9. **Función Polinomial (Grado 4)**
#    Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^{4} - 4x^{2} + 3$, $x = -1.5$, $x = 1.5$ y el eje $x$.
#
#    #### Metodología para trazar una región a mano:
#    1. Traza el gráfico de la función con el método de trazado de puntos.
#    2. Traza las rectas verticales.
#    3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.
#
# 10. **Función Racional (Cuadrática en el Denominador)**
#     Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \frac{1}{x^{2}+1}$, $x = -2$, $x = 2$ y el eje $x$.
#
#     #### Metodología para trazar una región a mano:
#     1. Traza el gráfico de la función con el método de trazado de puntos.
#     2. Traza las rectas verticales.
#     3. Resalta el eje $x$ que acota por debajo a la región bajo la curva.

# %% [markdown]
# # Áreas bajo la curva

# %% [markdown]
# El objetivo de esta clase no es la enseñanza del método de rebanado, aproximación a rectángulos de ancho $\Delta x$ para finalmente integrar sino interpretar el área de una región como una integral definida.

# %% [markdown]
# ## Áreas de regiones no triangulares y no cuadrangulares utilizando integración definida

# %% [markdown]
# Purcell página 280 de la sección 5.1.
#
# En los problemas del 1 al 10 utilice el procedimiento de tres pasos (rebanar, aproximar, integrar) para configurar y evaluar una integral (o integrales) para el área de la región que se indica.
#
#    1. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^{2} + 1$, $x = -1$, $x = 2$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# $$ \text{Área} = \int_{-1}^{2} (x^{2}+1) dx = 6 $$

# %%
# Trazado de la región del ejercicio 1 utilizando matplotlib
import numpy as np 
import matplotlib.pyplot as plt 
dominio_f = np.arange(-2, 3, 0.1)
dominio_integracion = np.arange(-1,2, 0.1)
def f(x):
    return x**2+1
rango_f = f(dominio_f)
rango_integracion = f(dominio_integracion)
plt.plot(dominio_f, rango_f)
plt.fill_between(dominio_integracion, rango_integracion)
plt.grid(alpha = 0.4)
#plt.axis('equal')
plt.savefig('/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_area/ejercicio_1_areas_bajo_la_curva_con_integral_purcell')

plt.show()

# %%
# solución del ejercicio 1 con sympy

from sympy import * 
x,y = var('x, y')
y = Function('y')(x)
y = x**2+1
integrate(y, (x, -1, 2))
# Out:
# 6

# %% [markdown]
# ## Conclusión verbal del ejercicio 1
# Por lo tanto, el área de la región del ejercicio 1 es 6 unidades de longitud al cuadrado.

# %% [markdown]
# ## Diez ejercicios de entrenamiento sobre determinación de áreas bajo la curva utilizando el concepto de integral definida
#
# Claro, aquí tienes 10 ejercicios similares para la determinación de áreas bajo la curva utilizando integración definida:

# %% [markdown]
# 1. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \sqrt{x}$, $x = 0$, $x = 4$ y el eje $x$. Dibuje la región y Determine el área de esta, utilizando integración definida.

# %% [markdown]
# 2. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \sin(x)$, $x = 0$, $x = \pi$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 3. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = e^{x}$, $x = 0$, $x = 1$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 4. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \cos(x)$, $x = 0$, $x = \frac{\pi}{2}$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 5. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \ln(x)$, $x = 1$, $x = e$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 6. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^3 - x$, $x = -1$, $x = 1$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 7. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = x^2 - 4x + 3$, $x = 1$, $x = 3$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 8. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = \frac{1}{x}$, $x = 1$, $x = 4$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 9. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = 2x - x^2$, $x = 0$, $x = 2$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# 10. Considere la región del plano acotada por las siguientes curvas: $y = f(x) = |x|$, $x = -2$, $x = 2$ y el eje $x$. Determine el área de esta región, utilizando integración definida.
#
# Espero que estos ejercicios sean útiles para tus estudios de cálculo e integración.

# %%
# Asignación de tareas para antes de clase  
# Tarea 1 sobre lectura de ejemplos 

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(42)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5.1'
numero_ejemplos_para_leer = 7
numero_de_ejercicios_asignados = 2


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejemplos_para_leer))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 1 asignada de lectura de ejemplos: ", assignment_csv)
assignment_df
# Out:
# Tarea 1 asignada de lectura de ejemplos:  tarea_Purcell_Página_280_Sección_5.1.csv
#                               Student  Example1  Example2
# 0        AGUDELO MORENO RENATO DIRNEY         2         3
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO         5         2
# 2       ARENAS HERAZO GABRIEL ENRIQUE         6         3
# 3        AYALA MENDOZA MARISOL YACIRA         2         7
# 4          BERTEL RODELO MICHELL SMIT         4         7
# 5            BULA VERGARA MARIA PAULA         7         4
# 6             CANTILLO ENSUCHO DANIEL         2         5
# 7            CERVANTES DURAN ANGELICA         2         3
# 8         GALLEGO TEJADA JUAN ESTEBAN         2         3
# 9             GUERRA NORIEGA YONATHAN         3         5
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN         7         5
# 11             HUMANEZ SANCHEZ CAMILO         7         4
# 12       IBAnEZ MORENO FRANCISCO LUIS         5         4
# 13  LONDONO CUADRADO CRISTIAN ALBERTO         6         3
# ...

# %%
# Asignación de tareas para realizar en clase
# Tarea 2 
# asignación de ejercicios de un seccion del texto guía

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5_1'
numero_ejercicios_taller = 38
numero_de_ejercicios_asignados = 7


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 2 asignada sobre determinacion de áreas: ", assignment_csv)
assignment_df
# Out:
# Tarea 2 asignada sobre determinacion de áreas:  tarea_Purcell_Página_280_Sección_5_1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     16      7     19     26     11
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     18     10     34     27      2
# 2       ARENAS HERAZO GABRIEL ENRIQUE      4     16     28     37      8
# 3        AYALA MENDOZA MARISOL YACIRA     29     35     30     16     10
# 4          BERTEL RODELO MICHELL SMIT     33      5      8     11     22
# 5            BULA VERGARA MARIA PAULA      6     38     32     18     11
# 6             CANTILLO ENSUCHO DANIEL      7     26      3     20     10
# 7            CERVANTES DURAN ANGELICA      7     29     23     20     19
# 8         GALLEGO TEJADA JUAN ESTEBAN     29     19     37     13      5
# 9             GUERRA NORIEGA YONATHAN     22      7     27     32     33
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     34     24     26     32      6
# ...

# %%
# Asignación de tareas para realizar después de clase

import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5_1'
numero_ejercicios_taller = 38
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 3 Solución justificando y describiendo: ", assignment_csv)
assignment_df
# Out:
# Tarea 3 Solución justificando y describiendo:  tarea_Purcell_Página_280_Sección_5_1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY      7      2     26     20     22
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     16     28     10      4     11
# 2       ARENAS HERAZO GABRIEL ENRIQUE     16     24     21     11     18
# 3        AYALA MENDOZA MARISOL YACIRA     36      8     38     20     21
# 4          BERTEL RODELO MICHELL SMIT     12     23     27      4     38
# 5            BULA VERGARA MARIA PAULA     37     30      7     10     22
# 6             CANTILLO ENSUCHO DANIEL     25     14     28     16     24
# 7            CERVANTES DURAN ANGELICA     15     10      5     35     33
# 8         GALLEGO TEJADA JUAN ESTEBAN     19      9     37     15     34
# 9             GUERRA NORIEGA YONATHAN     19     30     16     25     26
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     14     27     16      3      8
# ...

# %% [markdown]
# # Asignación para el trabajo con decimales

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)
# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/fund_math.csv"
exercises = list(range(1, 135))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_1_3:precalculo_stewart_pagina_32.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df

# %% [markdown]
# ¡Por supuesto! Aquí tienes diez ejercicios sobre operaciones con números decimales:
#
# **Ejercicio 1: Suma de números decimales**
# $3.45 + 2.67 = ?$
#
# **Ejercicio 2: Resta de números decimales**
# $ 8.92 - 4.76 = ? $
#
# **Ejercicio 3: Multiplicación de números decimales**
# $ 2.3 \times 1.5 = ? $
#
# **Ejercicio 4: División de números decimales**
# \[ \frac{6.75}{2.5} = ? \]
#
# **Ejercicio 5: Suma y resta de números decimales**
# \[ (5.4 + 3.2) - 2.1 = ? \]
#
# **Ejercicio 6: Multiplicación y suma de números decimales**
# \[ 1.8 \times 2 + 4.6 = ? \]
#
# **Ejercicio 7: Resta y multiplicación de números decimales**
# \[ (7.3 - 2.1) \times 3 = ? \]
#
# **Ejercicio 8: División y resta de números decimales**
# \[ (9.6 \div 2) - 1.3 = ? \]
#
# **Ejercicio 9: Suma, resta y multiplicación de números decimales**
# \[ (6.7 + 2.4) - 3.1 \times 2 = ? \]
#
# **Ejercicio 10: Operaciones mixtas con números decimales**
# \[ (4.2 \times 2) + (9.3 - 1.8) = ? \]
#
# Recuerda seguir las reglas básicas de las operaciones matemáticas al resolver estos ejercicios. ¡Buena suerte!

# %% [markdown]
# # Asignación para la sección 1.2 del precaĺculo de stewart sobre potenciación y radicación.

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)


# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv"
exercises = list(range(1, 106))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_1_2:precalculo_stewart_pagina_21.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df
# Out:
# Asignaciones guardadas en tarea_seccion_1_2:precalculo_stewart_pagina_21.csv
#          Student  Exer1  Exer2  Exer3  Exer4  Exer5  Exercise 6  Exercise 7  \
# 0       leonardo     64     38     58     30     20          39         104
# 1    Duvan trejo     90      1      8     93      6          59          96
# 2          angel     43     82     66     29      8          71         102
# 3         camila     24     29     62     90     67          74          65
# 4  luis fernando     79     81     21    101     70         105          19
# 5        mariana     24     22     87     89      4          96          38
# 6    oscar david     17     34     18     80     93          51          84
# 7  duvan salgado     30     80     39     83     28           8          26
#
#    Exercise 8  Exercise 9  ...  Exer11  Exer12  Exer13  Exer14  Exer15  \
# 0          18          45  ...      51      28      21      35      82
# ...

# %% [markdown]
# # El teorema fundamental del cálculo

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)
# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv"
exercises = list(range(1, 78))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_4.4:purcell_pagina_243.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df
# Out:
# Asignaciones guardadas en tarea_seccion_4.4:purcell_pagina_243.csv
#          Student  Exer1  Exer2  Exer3  Exer4  Exer5  Exercise 6  Exercise 7  \
# 0       leonardo     16     21     37     20     62          35          53
# 1    Duvan trejo     28     47     19      9     17          42          74
# 2          angel     65     14      6      8     23          19          52
# 3         camila     50     46      9     31     72          11          47
# 4  luis fernando     26      8     58     49     10           1          69
# 5        mariana     30      3     42     69     14          58          45
# 6    oscar david     38     14     34     63     45          15          47
# 7  duvan salgado     66      6     25     64     14          65          43
#
#    Exercise 8  Exercise 9  ...  Exer11  Exer12  Exer13  Exer14  Exer15  \
# 0          15          52  ...      71      40      19       1      42
# 1          75          13  ...      59       7      44      18      55
# ...

# %% [markdown]
# ###  [Continue su aprendizaje en la siguiente clase a través del siguiente](https://github.com/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/1_areas_entre_curvas/4_%C3%A1rea_bajo_la_curva_y_%C3%A1rea_entre_curvas/1_area_bajo_la_curva/2_evaluacion_tareas_quis_parcial_area_bajo_la_curva.ipynb)
