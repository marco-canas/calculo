# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/2_desplazamiento_distancia/2_evaluacion_tarea_quiz_parcial_oral_desplazamiento_distancia_con_integral_definida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/2_desplazamiento_distancia/2_evaluacion_tarea_quiz_parcial_oral_desplazamiento_distancia_con_integral_definida.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación oral, de Tareas en cuadernos Jupyter, Quiz o Parcial de selección múltiple o de preguntas cerradas.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * [Hipervínculo para el cuaderno de enseñanza sobre desplazamiento y distancia](https://github.com/marco-canas/calculo/blob/main/classes/3_calculo_for_eng_licenciatura_administracion/4_how_to_measure_areas%3Aintegral_calculus/2_integral_definida/1_aplicaciones_integral_definida/2_desplazamiento_distancia/1_desplazamiento_y_distancia_con_integral_definida.ipynb)

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# # Diseño de evaluación oral de si se alcanzaron los objetivos de aprendizaje planteados
#
# * Describa verbalmente el objetivo de aprendizaje y evidencie de forma oral si lo logró o no.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# 1. ¿?
# 2. ¿?
# 3. ¿?
# 4. ¿?
# 5. ¿?

# %% [markdown]
# # Vocabulary
#
# 1. length: longitud
# 2. width: ancho.
#
# [length, width](https://voca.ro/1of14ffdXnZI)

# %%
# valoracion de la asistencia  

import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) # hacer que todos los valores de la columna Parcial seen de tipo float

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def asistencia():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Asistió {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    asistencia()
    guardar_cambios()
# Out:
# Llamando a ROSILLO TEJADA VANESA...
# Actualizado: ROSILLO TEJADA VANESA ahora tiene 0.12 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a BULA VERGARA MARIA PAULA...
# Cambios guardados en el archivo CSV.
# Llamando a GUERRA NORIEGA YONATHAN...
# Actualizado: GUERRA NORIEGA YONATHAN ahora tiene 0.31 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a IBAÑEZ MORENO FRANCISCO LUIS...
# Actualizado: IBAÑEZ MORENO FRANCISCO LUIS ahora tiene 0.23 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a SILVA ROYERO MAILY CRISTINA...
# Cambios guardados en el archivo CSV.
# Llamando a AYALA MENDOZA MARISOL YACIRA...
# Cambios guardados en el archivo CSV.
# Llamando a CANTILLO ENSUCHO DANIEL...
# Cambios guardados en el archivo CSV.
# Llamando a PEREZ REYES IVAN DARIO...
# Cambios guardados en el archivo CSV.
# Llamando a MONTERROSA SOTO ABRIL...
# Cambios guardados en el archivo CSV.
# ...

# %% [markdown]
# # 1. Evaluar las tareas realizadas de manera manúscrita

# %%
# Tarea 1 de lectura y completación de ejemplos 
# asignación de tarea para realizar antes de clase
# Consiste en leer y completar un ejemplo de texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_275_Sección_5.1'
numero_ejemplos_de_la_seccion = 7
numero_de_ejemplos_para_leer_y_completar = 6


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejemplos_de_la_seccion))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejemplos_para_leer_y_completar, \
                                        replace = False) + 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejemplos_para_leer_y_completar)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 1 sobre lectura a ejemplos: ", assignment_csv)
assignment_df
# Out:
# Tarea 1 sobre lectura a ejemplos:  tarea_Purcell_Página_275_Sección_5.1.csv
#                               Student  Example1  Example2  Example3  Example4  \
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO         2         3         4         5
# 1       ARENAS HERAZO GABRIEL ENRIQUE         2         3         4         5
# 2        AYALA MENDOZA MARISOL YACIRA         2         3         4         5
# 3          BERTEL RODELO MICHELL SMIT         2         3         4         5
# 4            BULA VERGARA MARIA PAULA         2         3         4         5
# 5             CANTILLO ENSUCHO DANIEL         2         3         4         5
# 6            CERVANTES DURAN ANGELICA         2         3         4         5
# 7             GUERRA NORIEGA YONATHAN         2         3         4         5
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN         2         3         4         5
# 9              HUMANEZ SANCHEZ CAMILO         2         3         4         5
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metodología
# 1. Graficar la región
# 2. Plantear la integral que define al área de la región
# 3. Evaluar la integral  

plt.axis([-3, 4, -5, 5])
incremento = 0.1
dominio = np.arange(-2, 3 + incremento, incremento)

def f(x):
    return -(x**2 / 3 - 4)

rango = f(dominio)
plt.plot(dominio, rango, color='red')
plt.fill_between(dominio, rango, color = 'blue')
# Agregar la línea horizontal en y = 0
plt.axhline(y=0, color='green')

# Agregar las líneas verticales en x = -2 y x = 3
plt.axvline(x=-2, color='green')
plt.axvline(x=3, color='green')

plt.show()

# %%
from sympy import * 
x = var('x')

f = -(x**2 / 3 - 4)

integrate(f, (x, -2, 3)).evalf()
# Out:
# 16.1111111111111

# %%
# Tarea 2 de solución de problemas 
# asignación de ejercicios de un seccion del texto guía

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5.1'
numero_ejercicios_taller = 38
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 2: solucionar utilizando integracion definida: ", assignment_csv)
assignment_df
# Out:
# Tarea 2: solucionar utilizando integracion definida:  tarea_Purcell_Página_280_Sección_5.1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO      4      7     11     16     19
# 1       ARENAS HERAZO GABRIEL ENRIQUE      2      9     10     12     13
# 2        AYALA MENDOZA MARISOL YACIRA      4      7      8     16     25
# 3          BERTEL RODELO MICHELL SMIT     10     12     15     16     18
# 4            BULA VERGARA MARIA PAULA      5      8     10     11     21
# 5             CANTILLO ENSUCHO DANIEL      2      6     11     15     18
# 6            CERVANTES DURAN ANGELICA      3      6      7     10     18
# 7             GUERRA NORIEGA YONATHAN      7     11     19     20     22
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN      5     10     13     19     24
# 9              HUMANEZ SANCHEZ CAMILO      7     10     11     13     22
# 10       IBAÑEZ MORENO FRANCISCO LUIS      6      8     20     21     24
# ...

# %% [markdown]
# # Ejercicios 32 de la sección 5.1 del Purcell página 280 del PDF y del libro
#
#
# 32. Un objeto se mueve a lo largo de una recta, de modo que su velocidad en el instante $t$ es $v(t) = \frac{1}{2} + sen (2t)$ pies por segundo. Encuentre el desplazamiento y la distancia recorrida por el objeto en el intervalo $0 \leq t \leq \frac{3\pi}{2}$.

# %%
import matplotlib.pyplot as plt 
import numpy  
a,b = 0, 3*np.pi/2
dominio = np.arange(0,3*np.pi/2, 0.1)

def v(t):
    return 1/2 + np.sin(2*t)

rango = v(dominio) 
plt.figure(figsize = (6,4))
plt.title('Gráfico de Velocidad vs tiempo') 
plt.xlabel('Tiempo t')
plt.ylabel('Velocidad v')
plt.plot(dominio, rango, color = 'red', label = 'Velocidad en cada instante') 

plt.axhline(y = 0, color = 'green') 
plt.grid(alpha = 0.3)
plt.xticks(np.arange(a,b, 0.2), rotation = 90) # metrizar el eje horizontal
plt.savefig('velocidad_senoidal_ejeccicio_32.png')

# %% [markdown]
# # Describa la velocidad a partir de la lectura del gráfico.

# %%
import matplotlib.pyplot as plt 
import numpy as np  

dominio = np.arange(0,3*np.pi/2, 0.01)

def v(t):
    return 1/2 + np.sin(2*t)
rango = abs(v(dominio)) 
plt.title('Gráfico del valor absoluto de la velocidad vs tiempo')
plt.plot(dominio, rango) 

plt.axhline(y = 0, color = 'green') 

plt.grid(alpha = 0.3)

# %%
def integrar(f, a, b):
    n = 1000_000
    deltax = (b-a)/n
    return np.sum([f(a + i*deltax)*deltax for i in range(n)])

desplazamiento = integrar(f = lambda t_: 1/2+np.sin(2*t_), a = 0, b = 3*np.pi/2)
np.round(desplazamiento, 2)
# Out:
# 3.36

# %%
distancia_recorrida = integrar(f = lambda t: abs(1/2+np.sin(2*t)), a = 0, b = 3*np.pi/2)
np.round(distancia_recorrida, 2)
# Out:
# 4.04

# %%
# trayectoria de un objeto que se mueve horizontalmente

# descripción animada utilizando deslizadores gracias a la funcion interact
from sympy import * 
tiempo, posicion, velocidad, tiempo_para_posicion_12, tiempo_para_distancia_12  = \
    var('tiempo, posicion, velocidad, tiempo_para_posicion_12, tiempo_para_posicion_12 ')

velocidad = 5 - 3*tiempo  # definir la velocidad como función simbólica de sympy

valor_absoluto_de_la_velocidad = abs(velocidad)


import numpy as np 
import matplotlib.pyplot as plt 
from sympy import * 
tiempo = var('tiempo')
from ipywidgets import interact    

velocidad = (1/2) + sin(2*tiempo)

velocidad_lambda = lambdify(tiempo, velocidad) # convertir las funciones simbólicas de sympy en funciones numéticas lambda de python
valor_absoluto_de_la_velocidad_lambda = lambdify(tiempo, valor_absoluto_de_la_velocidad)




def trazar_particula_en_movimiento_horizontal(t = 0):
    a,b = -0.5,3.50
    def posicion(t):
        return integrar(f = lambda t_: 1/2+np.sin(2*t_), a = 0, b = t)

    distancia = integrar(f = lambda t_: abs(1/2+np.sin(2*t_)), a = 0, b = t)
        
    plt.scatter([posicion(t)], [0], linewidth = 8, color = 'red',\
                 label = f'la distancia recorrida por la partícula es {distancia:.2f}') 
    
    plt.axis([a, b, -0.1, 0.5])
    plt.legend()
    plt.grid(alpha = 0.4)
    plt.xticks(np.arange(a,b, 0.3))
    plt.xlabel('posición de la partícula')
    plt.title('Simulación de un movimiento rectímineo en donde hay cambio de sentido de movimiento')
    plt.axhline(y = 0, xmin = a, xmax = b)
    plt.show() 


interact(trazar_particula_en_movimiento_horizontal, t = (0, 3*np.pi/2, 0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=4.71238898038469), Output()), _dom_classes=(…
# <function __main__.trazar_particula_en_movimiento_horizontal(t=0)>

# %% [markdown]
# ## Describa el movimiento del objeto utilizando la animación obtenida con ipywidgets

# %%
from sympy import * 
t = symbols('t', real = True)  
v = 1/2 + sin(2*t)
solveset(v < 0, t, domain = Interval(0, 3*pi/2))
# Out:
# EmptySet

# %%
plot(Abs(v), title = 'Valor absoluto de v')

# %%
solve(v >= 0, t)
# Out:
# t < pi

# %%
distancia = integrate(Abs(v), (t, 0, 3*pi/2)).evalf() 
distancia
# Out:
# -0.214601836602552

# %%
# Tarea para después de la clase: asignación de ejercicios de un seccion del texto guía

# Tarea para adquisición de habilidades


import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
assignment_df
# Out:
# Tarea asignada:  tarea_Purcell_Página_202_Sección_3.8.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     48     22      2     50     53
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     37     18     20     42     28
# 2       ARENAS HERAZO GABRIEL ENRIQUE     29     47     49     33     26
# 3        AYALA MENDOZA MARISOL YACIRA     45     35      7     48     26
# 4          BERTEL RODELO MICHELL SMIT     41     14     29     16     25
# 5            BULA VERGARA MARIA PAULA     22     46      5     10     21
# 6             CANTILLO ENSUCHO DANIEL     19     50     46     14     48
# 7            CERVANTES DURAN ANGELICA     16     20     13     24      6
# 8         GALLEGO TEJADA JUAN ESTEBAN     36     11     49     47     37
# 9             GUERRA NORIEGA YONATHAN     47     43     51      6     46
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     35     51      2     33     18
# ...

# %% [markdown]
# # 3. Evaluar con un quiz escrito

# %%
# Quiz escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 2


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises
# Out:
# array([48, 22])

# %% [markdown]
# 4. Evaluar con un parcial escrito.

# %%
# Parcial escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 5


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises
# Out:
# array([48, 22,  2, 50, 53])

# %% [markdown]
# # 5. Evaluación oral
# ## 5. Evaluar la capacidad de describir un problema y su solución de manera oral.
#
# 1. Evaluaremos la capacidad de describir cada uno de los pasos o fases para resolver un problema (Es decir, se pedirá al estudiante que describa la metodología de solución de un problema dado).

# %%
# Llamar a lista o tomar asistencia con python 

import pandas as pd # convertir la lista de estudiantes en un dataframe
import numpy as np # elección aleatoria

# Cargar la lista de estudiantes desde la URL
url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/english.csv'
estudiantes = pd.read_csv(url) # convierte el csv en una dataframe

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def llamar_estudiante():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# %%
llamar_estudiante()
# Out:
# Llamando a Maro Julio Canas...

# %%
# Tarea para antes de realizada la clase
# Consiste en la lectura y completación de un ejemplo del texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 1


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
print('Debe transcribir el ejemplo \n en su cuaderno manuscrito y Jupyter y completar los procedimientos')
assignment_df
# Out:
# Tarea asignada:  tarea_Purcell_Página_202_Sección_3.8.csv
# Debe transcribir el ejemplo
#  en su cuaderno manuscrito y Jupyter y completar los procedimientos
#                               Student  Example1
# 0        AGUDELO MORENO RENATO DIRNEY        39
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO         2
# 2       ARENAS HERAZO GABRIEL ENRIQUE        37
# 3        AYALA MENDOZA MARISOL YACIRA         4
# 4          BERTEL RODELO MICHELL SMIT        12
# 5            BULA VERGARA MARIA PAULA        51
# 6             CANTILLO ENSUCHO DANIEL         5
# 7            CERVANTES DURAN ANGELICA        49
# 8         GALLEGO TEJADA JUAN ESTEBAN        28
# 9             GUERRA NORIEGA YONATHAN        33
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN        27
# 11             HUMANEZ SANCHEZ CAMILO        46
# 12       IBAnEZ MORENO FRANCISCO LUIS        26
# 13  LONDONO CUADRADO CRISTIAN ALBERTO        42
# 14          MASS MIRANDA RIVALDO JOSE        16
# ...

# %% [markdown]
# # Programa para evaluación del seguimiento mensual de los estudiantes

# %%
# Programa para valoración cuantitativa por meses para los estudiantes de todos los cursos
import numpy as np 
import pandas as pd   

#weights
weightAssistance = 12/100
weightAttentionParticipation = 8/100
weightHandwrittenNotebook = 8/100
weightJupyterNotebook = 20/100
weightQuiz = 16/100
weightPartial = 48/100

url_group = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/seminario_didactica_aritmetica.csv'

df = pd.read_csv(url_group, decimal = ',') 

df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
df.HandwrittenNotebook = (df.HandwrittenNotebook/np.max(df.HandwrittenNotebook))*5.0
df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0  


df['FollowUp'] = df.Assistance*weightAssistance + \
                 df.AttentionParticipation*weightAttentionParticipation + \
                 df.HandwrittenNotebook*weightHandwrittenNotebook+\
                 df.JupyterNotebook*weightJupyterNotebook+\
                 df.Quiz*weightQuiz + \
                 df.Partial*weightPartial

df.FollowUp = df.FollowUp.round(1)

df[['Nombre', 'FollowUp']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_153111/772128541.py in ?()
#      14
#      15 df = pd.read_csv(url_group, decimal = ',')
#      16
#      17 df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
# ---> 18 df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
#      19 df.HandwrittenNotebook = (df.HandwrittenNotebook/np.max(df.HandwrittenNotebook))*5.0
#      20 df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0
#      21
#
# ~/Documentos/investigacion/didactica_ciencia_datos/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# ...

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Cuestionario para realizar labores de memorización y observación,  a la síntesis de la información

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar en el drive asociuado al correo institucional de la Universidad Nacional del Profesor Marso para albergar los archivosd de audio de fomento a la memoirización, enunciación y parafraseo de los resultados científicos, prtopiedades, reglas, etc.
#
# * Vocaroo

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %%
# Programa para valoración cuantitativa por meses para los estudiantes de todos los cursos
import numpy as np 
import pandas as pd   

# Weights
weightAssistance = 12/100
weightAttentionParticipation = 8/100
weight_tast_1_2_3 = 8/100
weightJupyterNotebook = 20/100
weightQuiz = 16/100
weightPartial = 48/100

url_group = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv'

df = pd.read_csv(url_group, decimal = ',') 

df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
df.task_1_2_3 = (df.task_1_2_3/np.max(df.task_1_2_3))*5.0
df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0  


df['FollowUp'] = np.round(df.Assistance*weightAssistance+\
    df.AttentionParticipation*weightAttentionParticipation+\
    df.HandwrittenNotebook*weight_task_1_2_3+\
    df.JupyterNotebook*weightJupyterNotebook+\
    df.Quiz*weightQuiz+\
    df.Partial*weightPartial,1)
df[['Nombre', 'FollowUp']]
# Out:
#                                Nombre  FollowUp
# 0        AGUDELO MORENO RENATO DIRNEY       2.8
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO       2.5
# 2       ARENAS HERAZO GABRIEL ENRIQUE       2.5
# 3        AYALA MENDOZA MARISOL YACIRA       2.7
# 4          BERTEL RODELO MICHELL SMIT       2.5
# 5            BULA VERGARA MARIA PAULA       2.5
# 6             CANTILLO ENSUCHO DANIEL       5.0
# 7            CERVANTES DURAN ANGELICA       3.4
# 8         GALLEGO TEJADA JUAN ESTEBAN       1.9
# 9             GUERRA NORIEGA YONATHAN       4.6
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN       3.8
# 11             HUMANEZ SANCHEZ CAMILO       4.7
# 12       IBAnEZ MORENO FRANCISCO LUIS       3.5
# 13  LONDONO CUADRADO CRISTIAN ALBERTO       2.0
# 14       LOZANO HOLGUIN LIZETH JOHANA       3.4
# 15          MASS MIRANDA RIVALDO JOSE       4.6
# 16     MIRANDA MARTINEZ CARLOS ANDRES       3.8
# 17              MONTERROSA SOTO ABRIL       2.6
# 18           NORIEGA JIMENEZ GABRIELA       2.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  30 non-null     object
#  1   Email                   30 non-null     object
#  2   AttentionParticipation  30 non-null     float64
#  3   JupyterNotebook         30 non-null     float64
#  4   Partial                 30 non-null     float64
#  5   Quiz                    30 non-null     float64
#  6   HandwrittenNotebook     30 non-null     float64
#  7   Assistance              30 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
