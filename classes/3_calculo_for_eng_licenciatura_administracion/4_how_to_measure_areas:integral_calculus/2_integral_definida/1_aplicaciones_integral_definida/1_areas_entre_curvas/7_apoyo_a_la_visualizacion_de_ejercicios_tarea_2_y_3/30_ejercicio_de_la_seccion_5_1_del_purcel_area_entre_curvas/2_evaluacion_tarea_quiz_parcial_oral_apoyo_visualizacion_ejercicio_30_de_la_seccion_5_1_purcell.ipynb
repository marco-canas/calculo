# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación de Tareas en cuadernos Jupyter, Quiz o Parcial.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * [Hipervínculo para el cuaderno de enseñanza]()
# 1. Evaluar las tareas realizadas de manera manúscrita
# 2. Evaluar las tareas realizadas en los cuadernos Jupyter. (Solo realizar la tercera parte de las tareas asignadas de manera manuscrita)
# 3. Evaluar con un quiz escrito
# 4. Evaluar con un parcial escrito.
# 5. Evaluar la capacidad de describir un problema y su solución de manera oral.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# # Diseño de evaluación oral de si se alcanzaron los objetivos de aprendizaje planteados
#
# * Describa verbalmente el objetivo de aprendizaje y evidencie de forma oral si lo logró o no.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# 1. ¿?
# 2. ¿?
# 3. ¿?
# 4. ¿?
# 5. ¿?

# %% [markdown]
# # Vocabulary
#
# 1. length: longitud
# 2. width: ancho.
#
# [length, width](https://voca.ro/1of14ffdXnZI)

# %% [markdown]
# # 1. Evaluar las tareas realizadas de manera manúscrita
# ## 2. Evaluar las tareas realizadas en los cuadernos Jupyter. (Solo realizar la tercera parte de las tareas asignadas de manera manuscrita)

# %%
# Tarea 1 para antes de realizada la clase
# Consiste en la lectura y completación de un ejemplo del texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5.1'
numero_ejemplos_taller = 7
numero_de_ejemplos_asignados = 4


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejemplos_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejemplos_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejemplos_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
print('Debe transcribir el ejemplo \n en su cuaderno manuscrito y Jupyter y completar los procedimientos')
assignment_df
# Out:
# Tarea asignada:  tarea_Purcell_Página_280_Sección_5.1.csv
# Debe transcribir el ejemplo
#  en su cuaderno manuscrito y Jupyter y completar los procedimientos
#                               Student  Example1  Example2  Example3  Example4
# 0        AGUDELO MORENO RENATO DIRNEY         6         7         2         5
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO         5         2         6         4
# 2       ARENAS HERAZO GABRIEL ENRIQUE         2         3         6         5
# 3        AYALA MENDOZA MARISOL YACIRA         3         5         7         6
# 4          BERTEL RODELO MICHELL SMIT         3         6         2         7
# 5            BULA VERGARA MARIA PAULA         5         2         6         4
# 6             CANTILLO ENSUCHO DANIEL         5         6         4         3
# 7            CERVANTES DURAN ANGELICA         7         3         6         4
# 8         GALLEGO TEJADA JUAN ESTEBAN         6         5         3         4
# 9             GUERRA NORIEGA YONATHAN         6         5         3         2
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN         3         4         6         2
# 11             HUMANEZ SANCHEZ CAMILO         2         4         5         7
# 12       IBAnEZ MORENO FRANCISCO LUIS         6         7         4         5
# 13  LONDONO CUADRADO CRISTIAN ALBERTO         3         5         4         2
# 14          MASS MIRANDA RIVALDO JOSE         2         7         4         5
# 15     MIRANDA MARTINEZ CARLOS ANDRES         3         5         4         7
# 16              MONTERROSA SOTO ABRIL         6         3         4         2
# 17           NORIEGA JIMENEZ GABRIELA         4         3         2         7
# 18             PEREZ REYES IVAN DARIO         5         6         7         4
# 19               PEREZ THERAN ERLINDA         4         5         7         6
# 20              PINEDA ROMERO YOSMERI         3         7         6         4
# 21         QUINONEZ CERVANTES MARIANA         3         7         5         4
# 22           QUIROZ DURAN JUAN MANUEL         5         2         6         7
# 23                 RAMOS PEREZ YANINE         5         3         4         2
# 24              RIVAS HOYOS ESTEFANIA         5         4         2         7
# 25              ROSILLO TEJADA VANESA         5         3         2         4
# 26          SANCHEZ PADILLA SILVESTRE         2         6         7         3
# 27        SILVA ROYERO MAILY CRISTINA         5         7         2         3
# 28          USUGA GEORGE JHON ESTIVEN         2         4         7         5

# %%
# Tarea2: Asignación de ejercicio para realizar en clase o en casa


import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5.1'
numero_ejercicios_taller = 38
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 2 asignada: ", assignment_csv)
assignment_df
# Out:
# Tarea 2 asignada:  tarea_Purcell_Página_280_Sección_5.1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     16      7     19     26     11
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     18     10     34     27      2
# 2       ARENAS HERAZO GABRIEL ENRIQUE      4     16     28     37      8
# 3        AYALA MENDOZA MARISOL YACIRA     29     35     30     16     10
# 4          BERTEL RODELO MICHELL SMIT     33      5      8     11     22
# 5            BULA VERGARA MARIA PAULA      6     38     32     18     11
# 6             CANTILLO ENSUCHO DANIEL      7     26      3     20     10
# 7            CERVANTES DURAN ANGELICA      7     29     23     20     19
# 8         GALLEGO TEJADA JUAN ESTEBAN     29     19     37     13      5
# 9             GUERRA NORIEGA YONATHAN     22      7     27     32     33
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     34     24     26     32      6
# 11             HUMANEZ SANCHEZ CAMILO      8     13     12     30     19
# 12       IBAnEZ MORENO FRANCISCO LUIS     11     31     25     36      7
# 13  LONDONO CUADRADO CRISTIAN ALBERTO     17     31     12     30     29
# 14          MASS MIRANDA RIVALDO JOSE      7     12     13     25     14
# 15     MIRANDA MARTINEZ CARLOS ANDRES     19     30     23     25     35
# 16              MONTERROSA SOTO ABRIL     21     28     10     20     18
# 17           NORIEGA JIMENEZ GABRIELA     13     15     37      2     14
# 18             PEREZ REYES IVAN DARIO      3     16     36     20     23
# 19               PEREZ THERAN ERLINDA     21     26     35      2     32
# 20              PINEDA ROMERO YOSMERI      4     26     30     25     33
# 21         QUINONEZ CERVANTES MARIANA     28     34     25     19     37
# 22           QUIROZ DURAN JUAN MANUEL     33     30     38     28     14
# 23                 RAMOS PEREZ YANINE     11     22     21     30     37
# 24              RIVAS HOYOS ESTEFANIA      2      3      7      5     10
# 25              ROSILLO TEJADA VANESA     22     31     19     12     21
# 26          SANCHEZ PADILLA SILVESTRE     10     35     21      6      3
# 27        SILVA ROYERO MAILY CRISTINA      9     28      5      8     31
# 28          USUGA GEORGE JHON ESTIVEN      3     35     30     37      6
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0       4     37     23     30      31
# 1      24     37     13      9      12
# 2       7     25     29     31      26
# 3      15     18     26     25      12
# 4      31     21     10     30      24
# 5      33     26     15      2      24
# 6      21     29      6     18      35
# 7      38     22     11     28      31
# 8      38     24     10     30      28
# 9      38     23     10     11      13
# 10     36     38     20     21       8
# 11     29     25     37     23      17
# 12     13     18     19     38      35
# 13      9     33      5     28      27
# 14     36     29     20      8      35
# 15      4     24     28     33      26
# 16     14      7      2      3       5
# 17      3     22     36     26       5
# 18     33     13     11     19      31
# 19     25      7     16     30      12
# 20     13      7     23     19      14
# 21      7     30     13     32      18
# 22     23      2     15      7      32
# 23     35     33     20     27      29
# 24     24     30     22     15      18
# 25     29     23     24     10      18
# 26     38      8     19      7      30
# 27     20      3      7     10      17
# 28     20     34     17     22      10

# %%
# Tarea 3 para después de la clase: asignación de ejercicios de un seccion del texto guía

# Tarea para adquisición de habilidades de descripción y justificación


import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_280_Sección_5.1'
numero_ejercicios_taller = 38
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 3 solución de problemas
      describiendo y justificando cada paso: """, assignment_csv)
assignment_df
# Out:
# Tarea 3 solución de problemas
#       describiendo y justificando cada paso:  tarea_Purcell_Página_280_Sección_5.1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY      7      2     26     20     22
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     16     28     10      4     11
# 2       ARENAS HERAZO GABRIEL ENRIQUE     16     24     21     11     18
# 3        AYALA MENDOZA MARISOL YACIRA     36      8     38     20     21
# 4          BERTEL RODELO MICHELL SMIT     12     23     27      4     38
# 5            BULA VERGARA MARIA PAULA     37     30      7     10     22
# 6             CANTILLO ENSUCHO DANIEL     25     14     28     16     24
# 7            CERVANTES DURAN ANGELICA     15     10      5     35     33
# 8         GALLEGO TEJADA JUAN ESTEBAN     19      9     37     15     34
# 9             GUERRA NORIEGA YONATHAN     19     30     16     25     26
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     14     27     16      3      8
# 11             HUMANEZ SANCHEZ CAMILO     33     34      4     27      5
# 12       IBAnEZ MORENO FRANCISCO LUIS     32     29     18     28     12
# 13  LONDONO CUADRADO CRISTIAN ALBERTO      3      5     32     33      6
# 14          MASS MIRANDA RIVALDO JOSE      2      4     34     18     27
# 15     MIRANDA MARTINEZ CARLOS ANDRES     27     15     26     17     24
# 16              MONTERROSA SOTO ABRIL     13     26     19     29     31
# 17           NORIEGA JIMENEZ GABRIELA     38     24      8     25     32
# 18             PEREZ REYES IVAN DARIO     18     24      5     23      7
# 19               PEREZ THERAN ERLINDA     14      8     10     18     22
# 20              PINEDA ROMERO YOSMERI     32      6     20      7     17
# 21         QUINONEZ CERVANTES MARIANA     19     17     14     36     21
# 22           QUIROZ DURAN JUAN MANUEL     11     35     34     28     30
# 23                 RAMOS PEREZ YANINE     15      8     31     28     32
# 24              RIVAS HOYOS ESTEFANIA     31      4     20     10     36
# 25              ROSILLO TEJADA VANESA     16     20      2     24     34
# 26          SANCHEZ PADILLA SILVESTRE      6     19     22      2     29
# 27        SILVA ROYERO MAILY CRISTINA     13      6     21      3     16
# 28          USUGA GEORGE JHON ESTIVEN     22     15     16     17     35
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0       4     31     35     10      29
# 1       2      8     20     33      34
# 2      23     28     17     36       6
# 3      27     28      7      2       5
# 4       8      9     13     30      26
# 5       8     19     38     29      15
# 6      33     17     27     20       5
# 7      23     18      4     17      24
# 8      30     32     12     24      29
# 9      13     21     28     20      22
# 10     32     20      6     13      22
# 11     35     11     38     22      32
# 12     22     10     11      8      19
# 13      7     23     29     38      16
# 14     25     32     35     28      38
# 15      5     35     18     25       4
# 16     16     25     35      4      21
# 17     10     30     15      9      35
# 18     38     12     33      4      21
# 19      6      5     15     35      34
# 20     34     36     37     30      22
# 21     10     11     30     24      33
# 22      4     38     16     19       8
# 23      6     16     21      7       3
# 24     15     37      3     13       2
# 25     23     33     37     29      36
# 26     15     14     30     13      26
# 27     35     23     37      7      14
# 28     20     23      9      2      26

# %% [markdown]
# # 3. Evaluar con un quiz escrito

# %%
# Quiz escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 2


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises
# Out:
# array([48, 22])

# %% [markdown]
# 4. Evaluar con un parcial escrito.

# %%
# Parcial escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 5


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises
# Out:
# array([48, 22,  2, 50, 53])

# %% [markdown]
# # 5. Evaluación oral
# ## 5. Evaluar la capacidad de describir un problema y su solución de manera oral.
#
# 1. Evaluaremos la capacidad de describir cada uno de los pasos o fases para resolver un problema (Es decir, se pedirá al estudiante que describa la metodología de solución de un problema dado).

# %%
# Llamar a lista o tomar asistencia con python 

import pandas as pd # convertir la lista de estudiantes en un dataframe
import numpy as np # elección aleatoria

# Cargar la lista de estudiantes desde la URL
url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/english.csv'
estudiantes = pd.read_csv(url) # convierte el csv en una dataframe

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def llamar_estudiante():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# %%
llamar_estudiante()
# Out:
# Llamando a Maro Julio Canas...

# %% [markdown]
# # Programa para evaluación del seguimiento mensual de los estudiantes

# %%
# Programa para valoración cuantitativa por meses para los estudiantes de todos los cursos
import numpy as np 
import pandas as pd   

#weights
weightAssistance = 12/100
weightAttentionParticipation = 8/100
weightHandwrittenNotebook = 8/100
weightJupyterNotebook = 20/100
weightQuiz = 16/100
weightPartial = 48/100

url_group = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv'

df = pd.read_csv(url_group, decimal = ',') 

df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
df.HandwrittenNotebook = (df.HandwrittenNotebook/np.max(df.HandwrittenNotebook))*5.0
df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0  


df['FollowUp'] = df.Assistance*weightAssistance + \
                 df.AttentionParticipation*weightAttentionParticipation + \
                 df.HandwrittenNotebook*weightHandwrittenNotebook+\
                 df.JupyterNotebook*weightJupyterNotebook+\
                 df.Quiz*weightQuiz + \
                 df.Partial*weightPartial

df.FollowUp = df.FollowUp.round(1)

df[['Nombre', 'FollowUp']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31151/3275238779.py in ?()
#      15 df = pd.read_csv(url_group, decimal = ',')
#      16
#      17 df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
#      18 df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
# ---> 19 df.HandwrittenNotebook = (df.HandwrittenNotebook/np.max(df.HandwrittenNotebook))*5.0
#      20 df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0
#      21
#      22
#
# ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'HandwrittenNotebook'

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Cuestionario para realizar labores de memorización y observación,  a la síntesis de la información

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar en el drive asociuado al correo institucional de la Universidad Nacional del Profesor Marso para albergar los archivosd de audio de fomento a la memoirización, enunciación y parafraseo de los resultados científicos, prtopiedades, reglas, etc.
#
# * Vocaroo

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
