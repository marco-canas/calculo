# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación oral, de Tareas en cuadernos Jupyter, Quiz o Parcial de selección múltiple o de preguntas cerradas.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * [Hipervínculo para el cuaderno de enseñanza]()
# 1. Evaluar las tareas realizadas de manera manúscrita
# 2. Evaluar las tareas realizadas en los cuadernos Jupyter. (Solo realizar la tercera parte de las tareas asignadas de manera manuscrita)
# 3. Evaluar con un quiz escrito
# 4. Evaluar con un parcial escrito.
# 5. Evaluar la capacidad de describir un problema y su solución de manera oral.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# # Diseño de evaluación oral de si se alcanzaron los objetivos de aprendizaje planteados
#
# * Describa verbalmente el objetivo de aprendizaje y evidencie de forma oral si lo logró o no.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# 1. ¿?
# 2. ¿?
# 3. ¿?
# 4. ¿?
# 5. ¿?

# %% [markdown]
# # Vocabulary
#
# 1. length: longitud
# 2. width: ancho.
#
# [length, width](https://voca.ro/1of14ffdXnZI)

# %%
# algoritmo para llamar a evaluación oral individual
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) 

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def eval_oral():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Se expresó bien y correco {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
#while lista_estudiantes:
#    eval_oral()
#    guardar_cambios()

# %% [markdown]
# # 1. Evaluar las tareas realizadas de manera manúscrita

# %%
# Tarea 1 de lectura y completación de ejemplos del texto guia 
# Consiste en la lectura y completación de un ejemplo del texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_281_Secion_5.2'
numero_ejemplos_texto = 6
numero_ejemplos_asignados = 5


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
examples = list(range(1, numero_ejemplos_texto))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(examples, numero_ejemplos_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_ejemplos_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_1_lectura_y_completacion_ejemplos" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 1 asignada: ", assignment_csv)
print('''Debe transcribir el ejemplo 
      en su cuaderno manuscrito y Jupyter
       y completar los procedimientos
      Si no incluye el enunciado o planteamiento del problema de cada ejercicio, 
      no se le valora la tarea rebaja  
       Si no incluye de la conclusión verbal de cada ejercicio, 
      entonces no se le valora la tarea''')
assignment_df
# Out:
# Tarea 1 asignada:  tarea_1_lectura_y_completacion_ejemplos_Purcell_Página_281_Secion_5.2.csv
# Debe transcribir el ejemplo
#       en su cuaderno manuscrito y Jupyter
#        y completar los procedimientos
#       Si no incluye el enunciado o planteamiento del problema de cada ejercicio,
#       no se le valora la tarea rebaja
#        Si no incluye de la conclusión verbal de cada ejercicio,
#       entonces no se le valora la tarea
#                               Student  Example1  Example2  Example3  Example4  \
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO         2         3         4         5
# 1       ARENAS HERAZO GABRIEL ENRIQUE         2         3         4         5
# 2        AYALA MENDOZA MARISOL YACIRA         2         3         4         5
# 3          BERTEL RODELO MICHELL SMIT         2         3         4         5
# 4            BULA VERGARA MARIA PAULA         2         3         4         5
# 5             CANTILLO ENSUCHO DANIEL         2         3         4         5
# 6            CERVANTES DURAN ANGELICA         2         3         4         5
# 7             GUERRA NORIEGA YONATHAN         2         3         4         5
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN         2         3         4         5
# 9              HUMANEZ SANCHEZ CAMILO         2         3         4         5
# 10       IBAÑEZ MORENO FRANCISCO LUIS         2         3         4         5
# 11          MASS MIRANDA RIVALDO JOSE         2         3         4         5
# 12     MIRANDA MARTINEZ CARLOS ANDRES         2         3         4         5
# 13              MONTERROSA SOTO ABRIL         2         3         4         5
# 14           NORIEGA JIMENEZ GABRIELA         2         3         4         5
# 15             PEREZ REYES IVAN DARIO         2         3         4         5
# 16               PEREZ THERAN ERLINDA         2         3         4         5
# 17              PINEDA ROMERO YOSMERI         2         3         4         5
# 18         QUINONEZ CERVANTES MARIANA         2         3         4         5
# 19                 RAMOS PEREZ YANINE         2         3         4         5
# 20              RIVAS HOYOS ESTEFANIA         2         3         4         5
# 21              ROSILLO TEJADA VANESA         2         3         4         5
# 22          SANCHEZ PADILLA SILVESTRE         2         3         4         5
# 23        SILVA ROYERO MAILY CRISTINA         2         3         4         5
# 24          USUGA GEORGE JHON ESTIVEN         2         3         4         5
#
#     Example5
# 0          6
# 1          6
# 2          6
# 3          6
# 4          6
# 5          6
# 6          6
# 7          6
# 8          6
# 9          6
# 10         6
# 11         6
# 12         6
# 13         6
# 14         6
# 15         6
# 16         6
# 17         6
# 18         6
# 19         6
# 20         6
# 21         6
# 22         6
# 23         6
# 24         6

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a PINEDA ROMERO YOSMERI...
# Cambios guardados en el archivo CSV.

# %%
# Tarea 2: Asignación de ejercicio
# Ejercicios para adquirir habilidades de solución de problemas

import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_286_Sección_5.2'
numero_ejercicios_taller = 41
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejercicios_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_2_resolver_problemas" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 2 Solución de problemas
      para adquirir la metodología: 
      La no inclusión del enunciado o planteamiento del problema de cada ejercicio rebaja 1.0
      La no inclusión de la conclusión verbal de cada ejercicio rebaja 1.0 
      """, assignment_csv)
assignment_df
# Out:
# Tarea 2 Solución de problemas
#       para adquirir la metodología:
#       La no inclusión del enunciado o planteamiento del problema de cada ejercicio rebaja 1.0
#       La no inclusión de la conclusión verbal de cada ejercicio rebaja 1.0
#        tarea_2_resolver_problemas_Purcell_Página_286_Sección_5.2.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO      4      7     14     16     21
# 1       ARENAS HERAZO GABRIEL ENRIQUE      2      4     10     12     22
# 2        AYALA MENDOZA MARISOL YACIRA      4      8     12     14     16
# 3          BERTEL RODELO MICHELL SMIT      2      5     10     14     23
# 4            BULA VERGARA MARIA PAULA      5      6      8     19     27
# 5             CANTILLO ENSUCHO DANIEL      6      8     10     13     14
# 6            CERVANTES DURAN ANGELICA      7      9     14     18     19
# 7             GUERRA NORIEGA YONATHAN      5     10     23     27     29
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN      7     10     11     13     28
# 9              HUMANEZ SANCHEZ CAMILO      6      8     20     21     24
# 10       IBAÑEZ MORENO FRANCISCO LUIS      8     12     13     17     20
# 11          MASS MIRANDA RIVALDO JOSE      6      7     10     11     13
# 12     MIRANDA MARTINEZ CARLOS ANDRES      2      5      9     12     25
# 13              MONTERROSA SOTO ABRIL      2      5      7     11     12
# 14           NORIEGA JIMENEZ GABRIELA      4     13     19     22     24
# 15             PEREZ REYES IVAN DARIO      2      5     14     24     26
# 16               PEREZ THERAN ERLINDA      3      6     15     16     19
# 17              PINEDA ROMERO YOSMERI     11     16     20     23     25
# 18         QUINONEZ CERVANTES MARIANA      4      7     13     14     18
# 19                 RAMOS PEREZ YANINE      4      7     11     18     21
# 20              RIVAS HOYOS ESTEFANIA      4     11     13     15     18
# 21              ROSILLO TEJADA VANESA      5     11     19     20     26
# 22          SANCHEZ PADILLA SILVESTRE      5      6      8     10     11
# 23        SILVA ROYERO MAILY CRISTINA      7     10     15     16     19
# 24          USUGA GEORGE JHON ESTIVEN      5      6     10     12     22
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0      23     30     31     35      41
# 1      28     31     37     38      41
# 2      19     28     30     32      35
# 3      24     27     37     38      40
# 4      29     35     36     37      38
# 5      15     25     26     31      36
# 6      23     26     28     32      35
# 7      30     35     36     40      41
# 8      33     34     36     39      40
# 9      26     30     33     34      35
# 10     25     28     32     33      35
# 11     20     24     31     35      40
# 12     27     28     29     34      35
# 13     14     19     21     32      35
# 14     26     28     36     38      40
# 15     27     28     32     39      41
# 16     23     31     33     38      39
# 17     26     30     32     33      34
# 18     25     26     27     29      38
# 19     29     34     35     37      40
# 20     20     34     36     37      40
# 21     27     33     36     40      41
# 22     15     18     25     28      37
# 23     26     31     33     34      37
# 24     24     27     29     31      39

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a PEREZ REYES IVAN DARIO...
# Cambios guardados en el archivo CSV.

# %%
# Tarea 3 : asignación de ejercicios de un seccion del texto guía
# En esta tarea, describes y justificas cada línea de procedimiento de solución
# Tarea para adquisición de habilidades solución, descripción y justificación


import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_286_Sección_5.2'
numero_ejercicios_taller = 41
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejercicios_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_3_resolver_describiendo_justificando" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 3 Descripción y Justificación:
      La no inclusión del enunciado de cada ejercicio rebaja 1.0 
    La no inclusión de la conclusión verbal de cada ejercicio rebaja 1.0 """, assignment_csv)
assignment_df
# Out:
# Tarea 3 Descripción y Justificación:
#       La no inclusión del enunciado de cada ejercicio rebaja 1.0
#     La no inclusión de la conclusión verbal de cada ejercicio rebaja 1.0  tarea_3_resolver_describiendo_justificando_Purcell_Página_286_Sección_5.2.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO      2      9     13     17     21
# 1       ARENAS HERAZO GABRIEL ENRIQUE      3      4     22     25     26
# 2        AYALA MENDOZA MARISOL YACIRA      2      5      6     13     18
# 3          BERTEL RODELO MICHELL SMIT      2      3      9     10     18
# 4            BULA VERGARA MARIA PAULA      4      5      6      7     15
# 5             CANTILLO ENSUCHO DANIEL      2     12     13     16     20
# 6            CERVANTES DURAN ANGELICA      3      5     13     15     17
# 7             GUERRA NORIEGA YONATHAN      6     10     11     22     24
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN      5      6      9     17     19
# 9              HUMANEZ SANCHEZ CAMILO      8     13     16     19     20
# 10       IBAÑEZ MORENO FRANCISCO LUIS      2     10     13     14     17
# 11          MASS MIRANDA RIVALDO JOSE      2      3     15     16     17
# 12     MIRANDA MARTINEZ CARLOS ANDRES      8     11     13     17     22
# 13              MONTERROSA SOTO ABRIL      7     10     13     16     19
# 14           NORIEGA JIMENEZ GABRIELA      2      5      6      7     11
# 15             PEREZ REYES IVAN DARIO      2      8     10     19     21
# 16               PEREZ THERAN ERLINDA      9     10     11     14     19
# 17              PINEDA ROMERO YOSMERI      6      8     10     16     23
# 18         QUINONEZ CERVANTES MARIANA      4      7     16     19     20
# 19                 RAMOS PEREZ YANINE     18     21     23     24     25
# 20              RIVAS HOYOS ESTEFANIA      3      8      9     12     14
# 21              ROSILLO TEJADA VANESA      3     12     16     19     20
# 22          SANCHEZ PADILLA SILVESTRE      2     18     19     23     31
# 23        SILVA ROYERO MAILY CRISTINA      3      6      8     13     16
# 24          USUGA GEORGE JHON ESTIVEN      9     10     11     13     20
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0      23     31     32     34      35
# 1      29     34     37     39      40
# 2      28     29     35     36      39
# 3      19     28     31     36      37
# 4      20     33     35     36      37
# 5      23     27     29     33      34
# 6      25     30     32     33      35
# 7      25     32     34     36      39
# 8      24     29     33     35      39
# 9      26     28     29     30      33
# 10     22     26     29     35      38
# 11     18     24     25     28      34
# 12     24     25     28     35      40
# 13     20     27     33     34      35
# 14     12     13     32     33      40
# 15     23     25     27     36      37
# 16     26     29     32     33      39
# 17     24     26     35     37      40
# 18     24     25     34     38      39
# 19     26     32     33     36      37
# 20     21     24     29     34      35
# 21     24     25     30     31      36
# 22     32     35     36     39      40
# 23     23     26     30     39      41
# 24     21     28     29     33      39

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a MIRANDA MARTINEZ CARLOS ANDRES...
# Actualizado: MIRANDA MARTINEZ CARLOS ANDRES ahora tiene 0.31 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.

# %% [markdown]
# # 3. Evaluar con un quiz escrito

# %%
# definición de los parámetros personalizados para el quiz
import numpy as np 
import pandas as pd 

url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral_documento_identidad.csv'

df = pd.read_csv(url)
#df.head()
#df.info()
df['Cédula'] = df.Cédula.astype(str)
#type(df.Cédula[0])
# tomar los seis primeros o los seis ultimos dígitos 
# para fomentar el trabajo concentrado en las pruebas escribas

seleccionar_primeros_seis_digitos_o_los_ultimos = True

indice_asociado_al_estudiante = 0

if seleccionar_primeros_seis_digitos_o_los_ultimos:
    seis_digitos_documento_identidad = df.Cédula.iloc[indice_asociado_al_estudiante][:6]
else:
    seis_digitos_documento_identidad = df.Cédula.iloc[indice_asociado_al_estudiante][-6:]    
df.Cédula.iloc[indice_asociado_al_estudiante], seis_digitos_documento_identidad

# %%
eval_oral()
guardar_cambios()

# %%
# Quiz escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 3


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises

# %% [markdown]
# # 4. Evaluar con un parcial escrito.

# %%
# definición de los parámetros personalizados para el parcial
import numpy as np 
import pandas as pd 

url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral_documento_identidad.csv'

df = pd.read_csv(url)
#df.head()
#df.info()
df['Cédula'] = df.Cédula.astype(str)
#type(df.Cédula[0])
# tomar los seis primeros o los seis ultimos dígitos 
# para fomentar el trabajo concentrado en las pruebas escribas

seleccionar_primeros_seis_digitos_o_los_ultimos = True

indice_asociado_al_estudiante = 0

if seleccionar_primeros_seis_digitos_o_los_ultimos:
    seis_digitos_documento_identidad = df.Cédula.iloc[indice_asociado_al_estudiante][:6]
else:
    seis_digitos_documento_identidad = df.Cédula.iloc[indice_asociado_al_estudiante][-6:]    
df.Cédula.iloc[indice_asociado_al_estudiante], seis_digitos_documento_identidad

# %%
# Parcial escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 5


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+1 
random_exercises

# %%
eval_oral()
guardar_cambios()

# %% [markdown]
# # 5. Evaluación oral
# ## 5. Evaluar la capacidad de describir un problema y su solución de manera oral.
#
# 1. Evaluaremos la capacidad de describir cada uno de los pasos o fases para resolver un problema (Es decir, se pedirá al estudiante que describa la metodología de solución de un problema dado).

# %%
# algoritmo para llamar a evaluación oral individual
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) 

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def eval_oral():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Se expresó bien y correco {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    eval_oral()
    guardar_cambios()
# Out:
# Llamando a MASS MIRANDA RIVALDO JOSE...
# Cambios guardados en el archivo CSV.
# Llamando a QUINONEZ CERVANTES MARIANA...
# Cambios guardados en el archivo CSV.
# Llamando a SANCHEZ PADILLA SILVESTRE...
# Cambios guardados en el archivo CSV.
# Llamando a SILVA ROYERO MAILY CRISTINA...
# Cambios guardados en el archivo CSV.
# Llamando a NORIEGA JIMENEZ GABRIELA...
# Cambios guardados en el archivo CSV.
# Llamando a PINEDA ROMERO YOSMERI...
# Cambios guardados en el archivo CSV.
# Llamando a GUERRA NORIEGA YONATHAN...
# Cambios guardados en el archivo CSV.
# Llamando a HINCAPIE CASTRO JOHAN SEBASTIAN...
# Cambios guardados en el archivo CSV.
# Llamando a MIRANDA MARTINEZ CARLOS ANDRES...
# Cambios guardados en el archivo CSV.
# Llamando a ROSILLO TEJADA VANESA...
# Cambios guardados en el archivo CSV.
# Llamando a PEREZ THERAN ERLINDA...
# Cambios guardados en el archivo CSV.
# Llamando a HUMANEZ SANCHEZ CAMILO...
# Cambios guardados en el archivo CSV.
# Llamando a ARENAS HERAZO GABRIEL ENRIQUE...
# Cambios guardados en el archivo CSV.
# Llamando a RIVAS HOYOS ESTEFANIA...
# Cambios guardados en el archivo CSV.
# Llamando a BULA VERGARA MARIA PAULA...
# Cambios guardados en el archivo CSV.
# Llamando a AMARIS FERNANDEZ SEBASTIAN CAMILO...
# Cambios guardados en el archivo CSV.
# Llamando a USUGA GEORGE JHON ESTIVEN...
# Cambios guardados en el archivo CSV.
# Llamando a BERTEL RODELO MICHELL SMIT...
# Cambios guardados en el archivo CSV.
# Llamando a IBAÑEZ MORENO FRANCISCO LUIS...
# Cambios guardados en el archivo CSV.
# Llamando a MONTERROSA SOTO ABRIL...
# Cambios guardados en el archivo CSV.
# Llamando a CERVANTES DURAN ANGELICA...
# Cambios guardados en el archivo CSV.
# Llamando a AYALA MENDOZA MARISOL YACIRA...
# Cambios guardados en el archivo CSV.
# Llamando a PEREZ REYES IVAN DARIO...
# Cambios guardados en el archivo CSV.
# Llamando a CANTILLO ENSUCHO DANIEL...
# Cambios guardados en el archivo CSV.
# Llamando a RAMOS PEREZ YANINE...
# Cambios guardados en el archivo CSV.

# %% [markdown]
# # Autoevaluación

# %%
import csv

def recolectar_datos_autoavaluacion():
    # Definir el nombre del archivo CSV
    nombre_archivo = 'autoevaluacion_estudiantes.csv'
    
    # Definir los encabezados para el archivo CSV
    encabezados = ['Nombre', 'Fortalezas', 'Áreas de Mejora']
    
    # Solicitar los datos del estudiante
    nombre = input("Ingrese su nombre: ")
    fortalezas = input("Describa sus fortalezas: ")
    areas_mejora = input("Describa las áreas en las que necesita mejorar: ")
    
    # Crear una lista con los datos del estudiante
    datos = [nombre, fortalezas, areas_mejora]
    
    # Abrir el archivo CSV para agregar los datos
    with open(nombre_archivo, mode='a', newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        
        # Verificar si el archivo está vacío para escribir los encabezados
        archivo_csv.seek(0, 2)  # Mover el cursor al final del archivo
        if archivo_csv.tell() == 0:  # Verificar si el archivo está vacío
            escritor_csv.writerow(encabezados)
        
        # Escribir los datos en el archivo CSV
        escritor_csv.writerow(datos)
    
    print("La autoevaluación se ha guardado correctamente.")

# Ejecutar la función para recolectar datos
recolectar_datos_autoavaluacion()
# Out:
# Ingrese su nombre:  marco
# Describa sus fortalezas:  amable, cariñoso, fiel, deportista
# Describa las áreas en las que necesita mejorar:  irritabilidad, mi resiliencia
# La autoevaluación se ha guardado correctamente.

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://github.com/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/grajales_lina_matemticas.pdf)
#
# * Duval, R. (2004). Semiosis y pensamiento humano: registros semióticos y aprendizajes intelectuales. Universidad del Valle.
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](https://github.com/marco-canas/fundamentos_logica/blob/main/referentes/2_uzcategui/uscategui.pdf)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/chollet/Fran%C3%A7ois%20Chollet%20-%20Deep%20Learning%20with%20Python-Manning%20(2018).pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/geron/Hands-On%20Machine%20Learning-3nd_Edition(2022).pdf)
#
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/mckinney/Wes_McKinney.pdf)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
