# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/4_didactica_aritmetica/blob/main/modelo_general_clase_aula_invertida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import pandas as pd
import random

# Cargar la lista de estudiantes desde la URL
url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv'
estudiantes = pd.read_csv(url)

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def llamar_estudiante():
    estudiante_aleatorio = random.choice(estudiantes['Nombre'])
    print(f"Llamando a {estudiante_aleatorio}...")
    
    
# Llamar a la función para realizar el proceso
llamar_estudiante()
# Out:
# Llamando a oscar david...

# %% [markdown]
# # Fórmulas de integración
#
# 1. La regla de la potencia: $$ \int x^{n} = \frac{x^{n+1}}{n+1}  + C$$

# %% [markdown]
# # Dificultades de aprendizaje encontradas
#
# 1. El cuadrado de una décima es una centésima: Problemas para calcular el cuadrado de un decimal.
# 2. El cuadrado de un cociente es el cociente de los cuadrados.
# 3. Alinear los iguales.
# 4. Dificultad de aplicación del teorema fundamental del cálculo.
# 5. Elevar al cuadrado no es multiplicar por 2

# %% [markdown]
# # Asignación para el trabajo con decimales

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)
# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/fund_math.csv"
exercises = list(range(1, 135))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_1_3:precalculo_stewart_pagina_32.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df

# %% [markdown]
# ¡Por supuesto! Aquí tienes diez ejercicios sobre operaciones con números decimales:
#
# **Ejercicio 1: Suma de números decimales**
# $3.45 + 2.67 = ?$
#
# **Ejercicio 2: Resta de números decimales**
# \[ 8.92 - 4.76 = ? \]
#
# **Ejercicio 3: Multiplicación de números decimales**
# \[ 2.3 \times 1.5 = ? \]
#
# **Ejercicio 4: División de números decimales**
# \[ \frac{6.75}{2.5} = ? \]
#
# **Ejercicio 5: Suma y resta de números decimales**
# \[ (5.4 + 3.2) - 2.1 = ? \]
#
# **Ejercicio 6: Multiplicación y suma de números decimales**
# \[ 1.8 \times 2 + 4.6 = ? \]
#
# **Ejercicio 7: Resta y multiplicación de números decimales**
# \[ (7.3 - 2.1) \times 3 = ? \]
#
# **Ejercicio 8: División y resta de números decimales**
# \[ (9.6 \div 2) - 1.3 = ? \]
#
# **Ejercicio 9: Suma, resta y multiplicación de números decimales**
# \[ (6.7 + 2.4) - 3.1 \times 2 = ? \]
#
# **Ejercicio 10: Operaciones mixtas con números decimales**
# \[ (4.2 \times 2) + (9.3 - 1.8) = ? \]
#
# Recuerda seguir las reglas básicas de las operaciones matemáticas al resolver estos ejercicios. ¡Buena suerte!

# %% [markdown]
# # Asignación para la sección 1.2 del precaĺculo de stewart sobre potenciación y radicación.

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)
# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv"
exercises = list(range(1, 106))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_1_2:precalculo_stewart_pagina_21.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df
# Out:
# Asignaciones guardadas en tarea_seccion_1_2:precalculo_stewart_pagina_21.csv
#          Student  Exer1  Exer2  Exer3  Exer4  Exer5  Exercise 6  Exercise 7  \
# 0       leonardo     64     38     58     30     20          39         104
# 1    Duvan trejo     90      1      8     93      6          59          96
# 2          angel     43     82     66     29      8          71         102
# 3         camila     24     29     62     90     67          74          65
# 4  luis fernando     79     81     21    101     70         105          19
# 5        mariana     24     22     87     89      4          96          38
# 6    oscar david     17     34     18     80     93          51          84
# 7  duvan salgado     30     80     39     83     28           8          26
#
#    Exercise 8  Exercise 9  ...  Exer11  Exer12  Exer13  Exer14  Exer15  \
# 0          18          45  ...      51      28      21      35      82
# 1          50          48  ...      67      45      15      84     102
# 2          51         104  ...      76      19      26      40      72
# 3          59         105  ...      54      39      98      64      76
# 4          85          63  ...      53      67      26      54      69
# 5          50          93  ...      30      45     104      84      83
# 6          81          25  ...      95       9      89      47      98
# 7          78          70  ...      86      24      45      13      34
#
#    Exer16  Exer17  Exer18  Exer19  exer20
# 0      53     105      94      17      70
# 1      26      33      39      79      71
# 2      17      13      84      31      68
# 3      51       5      70      42       6
# 4      11      49      64      33      10
# 5      13      72      43      37      71
# 6      74      88      70      37      41
# 7      35      95      69      53      20
#
# [8 rows x 21 columns]

# %% [markdown]
# # El teorema fundamental del cálculo

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests
np.random.seed(42)
# Descargar la lista de  estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv"
exercises = list(range(1, 78))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 20)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1", "Exer2", "Exer3","Exer4", "Exer5", \
           "Exercise 6", "Exercise 7", "Exercise 8", "Exercise 9", "exercise 10", \
           "Exer11", "Exer12", "Exer13","Exer14", "Exer15", \
           "Exer16", "Exer17", "Exer18", "Exer19", "exer20"
            ]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_4.4:purcell_pagina_243.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df
# Out:
# Asignaciones guardadas en tarea_seccion_4.4:purcell_pagina_243.csv
#          Student  Exer1  Exer2  Exer3  Exer4  Exer5  Exercise 6  Exercise 7  \
# 0       leonardo     16     21     37     20     62          35          53
# 1    Duvan trejo     28     47     19      9     17          42          74
# 2          angel     65     14      6      8     23          19          52
# 3         camila     50     46      9     31     72          11          47
# 4  luis fernando     26      8     58     49     10           1          69
# 5        mariana     30      3     42     69     14          58          45
# 6    oscar david     38     14     34     63     45          15          47
# 7  duvan salgado     66      6     25     64     14          65          43
#
#    Exercise 8  Exercise 9  ...  Exer11  Exer12  Exer13  Exer14  Exer15  \
# 0          15          52  ...      71      40      19       1      42
# 1          75          13  ...      59       7      44      18      55
# 2          16          69  ...      22      36      53      41      30
# 3          59          63  ...      32      16      73      77      75
# 4          13          59  ...      39      30      61      45      43
# 5          31          53  ...      33      72      40      64       5
# 6          58          52  ...      16      67      20      56      27
# 7           9          38  ...      36      60       2      73       5
#
#    Exer16  Exer17  Exer18  Exer19  exer20
# 0      68       5      43      50       4
# 1      15      26       6      48      24
# 2      31      48      64      46      29
# 3      69      35      23      71      13
# 4      25      63      68       5      20
# 5      50      26      74      77      67
# 6      53      55      44      76      29
# 7      22      17      26      71      47
#
# [8 rows x 21 columns]

# %%
4**(1/2)
# Out:
# 2.0

# %%
import numpy as np 

np.sqrt(4)

# %%
import math as m

m.sqrt(9)
# Out:
# 3.0

# %%
from sympy import * 
z = var('z')

# %%
integrate( z*cos((z**2+3)**(1/3))/((z**2+3)**(1/3))**2, z)
# Out:
# ---------------------------------------------------------------------------
# _CoeffExpValueError                       Traceback (most recent call last)
# /home/marco/Documentos/docencia/calculo/classes/4_integration/4_aplicaciones_integral/1_areas_entre_curvas/1_areas_entre_curvas.ipynb Celda 20 line 1
# ----> <a href='vscode-notebook-cell:/home/marco/Documentos/docencia/calculo/classes/4_integration/4_aplicaciones_integral/1_areas_entre_curvas/1_areas_entre_curvas.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> integrate( z*cos((z**2+3)**(1/3))/((z**2+3)**(1/3))**2, z)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/integrals.py:1567, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1564 integral = Integral(*args, **kwargs)
#    1566 if isinstance(integral, Integral):
# -> 1567     return integral.doit(**doit_flags)
#    1568 else:
#    1569     new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#    1570         for a in integral.args]
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/integrals.py:612, in Integral.doit(self, **hints)
#     610     antideriv = None
#     611 else:
# --> 612     antideriv = self._eval_integral(
#     613         function, xab[0], **eval_kwargs)
#     614     if antideriv is None and meijerg is True:
#     615         ret = try_meijerg(function, xab)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/integrals.py:1098, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1095 if meijerg is not False and h is None:
#    1096     # rewrite using G functions
#    1097     try:
# -> 1098         h = meijerint_indefinite(g, x)
#    1099     except NotImplementedError:
#    1100         _debug('NotImplementedError from meijerint_definite')
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1668, in meijerint_indefinite(f, x)
#    1666 results = []
#    1667 for a in sorted(_find_splitting_points(f, x) | {S.Zero}, key=default_sort_key):
# -> 1668     res = _meijerint_indefinite_1(f.subs(x, x + a), x)
#    1669     if not res:
#    1670         continue
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1694, in _meijerint_indefinite_1(f, x)
#    1691 _debug('Trying to compute the indefinite integral of', f, 'wrt', x)
#    1692 from sympy.simplify import hyperexpand, powdenest
# -> 1694 gs = _rewrite1(f, x)
#    1695 if gs is None:
#    1696     # Note: the code that calls us will do expand() and try again
#    1697     return None
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1618, in _rewrite1(f, x, recursive)
#    1610 """
#    1611 Try to rewrite ``f`` using a (sum of) single G functions with argument a*x**b.
#    1612 Return fac, po, g such that f = fac*po*g, fac is independent of ``x``.
#    (...)
#    1615 Return None on failure.
#    1616 """
#    1617 fac, po, g = _split_mul(f, x)
# -> 1618 g = _rewrite_single(g, x, recursive)
#    1619 if g:
#    1620     return fac, po, g[0], g[1]
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1572, in _rewrite_single(f, x, recursive)
#    1570     return Integral(f, (x, S.Zero, S.Infinity))
#    1571 try:
# -> 1572     F, strip, _ = mellin_transform(f, x, s, integrator=my_integrator,
#    1573                                    simplify=False, needeval=True)
#    1574     g = my_imt(F, s, x, strip)
#    1575 except IntegralTransformError:
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:405, in mellin_transform(f, x, s, **hints)
#     364 def mellin_transform(f, x, s, **hints):
#     365     r"""
#     366     Compute the Mellin transform `F(s)` of `f(x)`,
#     367
#    (...)
#     403     hankel_transform, inverse_hankel_transform
#     404     """
# --> 405     return MellinTransform(f, x, s).doit(**hints)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:161, in IntegralTransform.doit(self, **hints)
#     158 simplify = hints.pop('simplify', True)
#     159 hints['simplify'] = simplify
# --> 161 fn, T = self._try_directly(**hints)
#     163 if T is not None:
#     164     return T
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:125, in IntegralTransform._try_directly(self, **hints)
#     123 if try_directly:
#     124     try:
# --> 125         T = self._compute_transform(self.function,
#     126             self.function_variable, self.transform_variable, **hints)
#     127     except IntegralTransformError:
#     128         debug('[IT _try ] Caught IntegralTransformError, returns None')
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:344, in MellinTransform._compute_transform(self, f, x, s, **hints)
#     343 def _compute_transform(self, f, x, s, **hints):
# --> 344     return _mellin_transform(f, x, s, **hints)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:245, in _noconds_.<locals>.make_wrapper.<locals>.wrapper(noconds, *args, **kwargs)
#     243 @wraps(func)
#     244 def wrapper(*args, noconds=default, **kwargs):
# --> 245     res = func(*args, **kwargs)
#     246     if noconds:
#     247         return res[0]
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/transforms.py:268, in _mellin_transform(f, x, s_, integrator, simplify)
#     265 # We use a fresh dummy, because assumptions on s might drop conditions on
#     266 # convergence of the integral.
#     267 s = _dummy('s', 'mellin-transform', f)
# --> 268 F = integrator(x**(s - 1) * f, x)
#     270 if not F.has(Integral):
#     271     return _simplify(F.subs(s, s_), simplify), (S.NegativeInfinity, S.Infinity), S.true
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1563, in _rewrite_single.<locals>.my_integrator(f, x)
#    1562 def my_integrator(f, x):
# -> 1563     r = _meijerint_definite_4(f, x, only_double=True)
#    1564     if r is not None:
#    1565         from sympy.simplify import hyperexpand
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:2048, in _meijerint_definite_4(f, x, only_double)
#    2045             return _my_unpolarify(hyperexpand(res)), cond
#    2047 # Try two G functions.
# -> 2048 gs = _rewrite2(f, x)
#    2049 if gs is not None:
#    2050     for full_pb in [False, True]:
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1632, in _rewrite2(f, x)
#    1624 """
#    1625 Try to rewrite ``f`` as a product of two G functions of arguments a*x**b.
#    1626 Return fac, po, g1, g2 such that f = fac*po*g1*g2, where fac is
#    (...)
#    1629 Returns None on failure.
#    1630 """
#    1631 fac, po, g = _split_mul(f, x)
# -> 1632 if any(_rewrite_single(expr, x, False) is None for expr in _mul_args(g)):
#    1633     return None
#    1634 l = _mul_as_two_parts(g)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1632, in <genexpr>(.0)
#    1624 """
#    1625 Try to rewrite ``f`` as a product of two G functions of arguments a*x**b.
#    1626 Return fac, po, g1, g2 such that f = fac*po*g1*g2, where fac is
#    (...)
#    1629 Returns None on failure.
#    1630 """
#    1631 fac, po, g = _split_mul(f, x)
# -> 1632 if any(_rewrite_single(expr, x, False) is None for expr in _mul_args(g)):
#    1633     return None
#    1634 l = _mul_as_two_parts(g)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:1523, in _rewrite_single(f, x, recursive)
#    1521 res = []
#    1522 for fac, g in terms:
# -> 1523     r1 = _get_coeff_exp(unpolarify(fac.subs(subs).subs(z, x),
#    1524                                    exponents_only=True), x)
#    1525     try:
#    1526         g = g.subs(subs).subs(z, x)
#
# File ~/Documentos/docencia/calculo/.venv/lib/python3.10/site-packages/sympy/integrals/meijerint.py:350, in _get_coeff_exp(expr, x)
#     348     return c, S.One
#     349 else:
# --> 350     raise _CoeffExpValueError('expr not of form a*x**b: %s' % expr)
#
# _CoeffExpValueError: expr not of form a*x**b: 0.355028053887817

# %%
diff((3/2)*sin((z**2+3)**(1/3)), z)
# Out:
# 1.0*z*cos((z**2 + 3)**0.333333333333333)/(z**2 + 3)**0.666666666666667
