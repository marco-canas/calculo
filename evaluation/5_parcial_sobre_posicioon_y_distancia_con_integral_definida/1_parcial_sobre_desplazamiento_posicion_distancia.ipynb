# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia
#
# Aquí tienes algunas mujeres destacadas en Colombia en la enseñanza de la matemática, junto con una breve biografía de cada una:

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) # hacer que todos los valores de la columna Parcial seen de tipo float

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def asistencia():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Asistió {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    asistencia()
    guardar_cambios()
# Out:
# Llamando a ROSILLO TEJADA VANESA...
# Cambios guardados en el archivo CSV.
# Llamando a QUINONEZ CERVANTES MARIANA...

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# ![Definamos flipped learning de manera gráfica](https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png)

# %% [markdown]
# # Metodología de enseñanza basada en problemas (ABP)
#
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg'>

# %% [markdown]
# # Desarrollo del pensamiento coomputacional con python y cuadernos Jupyter  orientado a la formación en ciencia de datos
#
#
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg'>

# %% [markdown]
# # Proncipio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto
#
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1'>

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas

# %% [markdown]
# ## Título de la clase: Diseño y reflexión pedagógica en el parcial sobre aplicación de la integral definida al cálculo del desplazamiento, la posición y la distancia recorrida de un objeto en un movimiento rectilíneo.
#
# [Obtenga sl texto de purcell aquí](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)

# %% [markdown]
# * Que el ingeniero pueda aprender a describir un movimiento rectilíneo dada su velocidad y posición inicial. Y utilizando el concepto de integral definida.

# %%
# Traducción del inglés al español con python

def traducir(texto):
    from googletrans import Translator

    translator = Translator() # instancia la clase 

    # Traducir al español
    translation = translator.translate(texto, src='en', dest='es')
    return translation.text

# %%
traducir('Hi')
# Out:
# 'Hola'

# %%
# mapa conceptual para cada clase  
from graphviz import Digraph

# Crear un nuevo grafo dirigido
dot = Digraph()

# Añadir nodos y relaciones al grafo
main_concept = 'Integral definida \n para descripción de movimiento rectilíneo '
dot.node('A', main_concept)
dot.node('B', '')
dot.node('C', '')
dot.node('D', '')
dot.node('E', '')
dot.node('F', '')
dot.node('G', '')
dot.node('H', '')
dot.node('I', '')
dot.node('J', '')

dot.edges(['AB'])
dot.edges(['AC'])
dot.edges(['CD'])
dot.edges(['DJ'])
dot.edges(['EF'])
dot.edges(['FG'])
dot.edges(['GH'])
dot.edges(['HI'])
dot.edges(['IJ'])

# Guardar el grafo como un archivo de imagen
dot.render(filename=main_concept, format='png', cleanup=True, \
           directory='/home/marco/Documentos/docencia/calculo/images/0_reales/')

dot.view()
# Out:
# '/home/marco/Documentos/docencia/calculo/images/0_reales/Integral definida \n para descripción de movimiento rectilíneo .pdf'

# %% [markdown]
# # Primer punto del parcial sobre determinación de áreas bajo la curva
#
# * Trace el gráfico de la función $y = f(x) = cx^{2} - dx + e$ a mano utilizando el método de trazado de puntos y trace las rectas verticales $x = a$ y $x = b$ y resalte la reta horizontal $y = 0$ (donde $a, b, c, d, e$) son los cinco últimos números de su documento de identidad.
# * Identifique el tipo de función.
# * Sombree la región acotada por las curvas anteriores.
# * Determine $$\int_{a}^{b}f(x)\ dx$$
# * Redacte la interpretación geométrica del resultado anterior.

# %% [markdown]
# # Diseño y reflexión pedagógica en el parcial sobre aplicación de la integral definida al cálculo del desplazamiento, la posición y la distancia recorrida de un objeto en un movimiento rectilíneo.

# %% [markdown]
# ## Planteamiento de la situación física
#
# 33. Iniciando en $s = 0$ cuando $t = 0$, un objeto se mueve a lo largo de una recta de modo que su velocidad en el instante $t$ es $v(t) = mt + b$ centímetros por segundo.
#
#     1. Trace o grafique la función velocidad siguiendo el método de trazado de puntos: (tabla, traza puntos en el plano, une con segmentos).
#
#     2. ¿Cuánto tiempo le toma llegar a la posición $s = p$?
#         * Puede utilizar el hecho de que lla integral indefinida de la velocidad es la posición más C
#         * Tambien puede utilizar que la integral definida de la velocidad es el desplazamiento.
#     3. ¿Cuánto tiempo le toma recorrer una distancia total de $p$ centímetros?
#         * Puede inferir la distancia recorrida utilizando el gráfico de la velocidad y el análisis de su signo.
#         * puede calcular la distancia, evaluando la integral definida del valor absoluto de la velocidad.
#     4. Determine el área del triángulo, utilizando la fórmula de área de un triángulo, determinado por la función velocidad, el eje $x$ y la recta $t = $ tiempo necesario para alcanzar la posición $p$.
#
# Donde $m, b$ y $p$ son los primeros tres dígitos **no núlos** de su documento de identidad.
#
# Ejercicios tomado de Purcell, página 280.

# %% [markdown]
# # Solución

# %%
import pandas as pd

# Ruta al archivo CSV
path = '/home/marco/Documentos/docencia/groups_list/calculo_vectorial.csv'

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(path)

# Pedir al usuario el inicio del nombre del estudiante
nombre_inicio = input("Ingrese el inicio del nombre del estudiante: ").upper()

# Filtrar el DataFrame para encontrar el estudiante cuyo nombre comienza con la entrada del usuario
df_filtrado = df[df['Nombre'].str.startswith(nombre_inicio, na=False)]

# Comprobar si se encontró algún estudiante
if not df_filtrado.empty:
    # Obtener la primera fila del DataFrame filtrado
    estudiante = df_filtrado.iloc[0]

    # Obtener la cédula del estudiante
    cedula = estudiante['Cedula']

    # Convertir la cédula a una cadena y remover ceros iniciales
    cedula_str = str(cedula).lstrip('0')

    # Extraer los primeros tres dígitos no nulos
    if len(cedula_str) >= 3:
        m, b, p = int(cedula_str[0]), int(cedula_str[1]), int(cedula_str[2])
        print(f"Los primeros tres dígitos de la cédula son: m={m}, b={b}, p={p}")
    else:
        print("La cédula tiene menos de tres dígitos después de eliminar los ceros iniciales.")
else:
    print("No se encontró ningún estudiante con ese nombre.")
# Out:
# Los primeros tres dígitos de la cédula son: m=1, b=1, p=9

# %%
 a_, b_, m, b, p,= 1,9,4,8,1

# %%
estudiante.Cedula, estudiante.Nombre
# Out:
# (1193404816, 'AMARIS FERNANDEZ SEBASTIAN CAMILO')

# %%
# gráfico de la región definida 

import numpy as np 
import matplotlib.pyplot as plt 

incremento = 0.1
dominio = np.arange(a_, b_+incremento, incremento)
def f(x):
    return m*x**3-b*x + p
rango = f(dominio) 

def integrar(f, a, b):
    n = 1000_000
    deltax = (b-a)/n
    return np.sum([f(a + i*deltax)*deltax for i in range(n)])

plt.figure(figsize = (6,4))
plt.title(f'Region del estudiante {estudiante.Nombre}')
plt.axis([a_ - 1, b_ + 1, np.min([f(a_), f(b_)]) - 1, np.max([f(a_), f(b_)]) + 1])
plt.plot(dominio, rango, color = 'red', label = f'funcion {m}x³-{b}x + {p}')
plt.fill_between(dominio, rango, color = 'blue')
plt.axhline(y = 0, color = 'green', label = f'límites de integracion {a_} y {b_}') 
plt.axvline(x=0, label = f'la integral da: {np.round(integrar(f, a_,b_), 1)}')
plt.grid(alpha = 0.3)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend() 

plt.savefig('/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/2_areas/'+f'punto_area_integral_definida{estudiante.Nombre}'+'.jpg')
plt.show()

# %% [markdown]
# ## Inferencias de la lectura del gráfico de la función
#
# * Cómo el gráfico de $f$ está por encima del eje $x$, entonces la función es no netativa y por tanto, la integral definida de esta función representa el área bajo la curva.

# %%
estudiante['Cedula']
# Out:
# 1038131734

# %%
import matplotlib.pyplot as plt 

m,b = 1,0
dominio = np.arange(start = 0, stop = 12, step = 2)
def v(t):
    return m*t+b
rango = v(dominio)
plt.title(f'Gráfico de la función de velocidad {estudiante.Nombre}')
plt.plot(dominio, rango, color = 'red', label = f'Función velocidad {m}t+({b})') 

plt.axhline(y = 0, color = 'green')
plt.axvline(x=0, color = 'green')
plt.grid(alpha = 0.3)
plt.xlabel('tiempo')
plt.ylabel('Velocidad')

plt.legend() 

plt.savefig('/home/marco/Documentos/docencia/calculo/images/4_integral/2_aplicaciones_integral_definida/3_desplazamiento_distancia/grafico_velocidad_ejercicio_33_seccion_5_1_purcell.jpg')

# %% [markdown]
# ## Inferencias de la lectura del gráfico de velocidad
#
# * Una velocidad con gráfico por encima del eje x significa, velocidad no negativa, lo que implica que el cuerpo se mueve en un solo sentido (solo a la derecha)..

# %%
# animación de movimiento a lo largo de una trayectoria horizontal
# descripción animada utilizando deslizadores gracias a la funcion interact  
import numpy as np 
import matplotlib.pyplot as plt 
from ipywidgets import interact    
m,b = 1,0
def trazar_particula_en_movimiento_horizontal(t = 0):
    a_,b_ = -0.5,10 # Dominio de graficación
    posicion=integrar(lambda t_:m*t_+b, a = 0, b = t)
    distancia = integrar(lambda t_:abs(m*t_+b), a = 0, b = t)
    plt.figure(figsize = (8,6))  
    plt.axhline(y = 0, xmin = a_, xmax = b_, label = f'Velocidad: {m}t + {b}')  
    plt.axvline(x=0, label=f'Posición alcanzada {posicion:.2f}')
    plt.scatter([posicion], [0], linewidth = 8, color = 'red',\
                 label = f'la distancia recorrida es {distancia:.2f}') 
    plt.axis([a_, b_, -0.1, 0.5])
    
    plt.grid(alpha = 0.4)
    incremento = 0.4
    plt.xticks(np.arange(a_,b_+incremento, incremento), rotation = 90)
    plt.xlabel('posición de la partícula en centímetros')
    plt.title('Simulación de un movimiento rectímineo en donde hay cambio de sentido de movimiento')
    
    plt.legend()

    plt.show() 


interact(trazar_particula_en_movimiento_horizontal, t = (0, 10, 0.01))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=10.0, step=0.01), Output()), _dom_classes=('…
# <function __main__.trazar_particula_en_movimiento_horizontal(t=0)>

# %% [markdown]
# Sea $s(t_{transcurrido})$ es la posición al cabo de $t_{transcurrido}$
#
# Encontremos la función posición $s(t_{transcurrido})$
#
# $$ v(t) = mt + b $$
#
# $$ s(tiempo_{transcurrido}) = \int_{0}^{tiempo_{transcurrido}} v(t) dt $$

# %% [markdown]
# Modelo de la situación problemática
#
# $$ s(tiempo_{transcurrido}) = p \quad  \equiv \quad  s(tiempo_{transcurrido}) - p = 0 $$
#
# $$  \int_{0}^{tiempo_{transcurrido}} v(t) dt = p \qquad \equiv \qquad \int_{0}^{tiempo_{transcurrido}} v(t) dt - p = 0  $$

# %%
m,b = 1,3
def integrar(f, a, b):
    n = 1000_000
    deltax = (b-a)/n
    return np.sum([f(a + i*deltax)*deltax for i in range(n)])

def posicion(tiempo_transcurrido):
    return integrar(f = lambda t_: m*t_+b, a = 0, b = tiempo_transcurrido)


def distancia(tiempo_transcurrido):
    return integrar(f = lambda t_: abs(m*t_+b), a = 0, b = tiempo_transcurrido)

# %%
from scipy.optimize import brentq
import numpy as np
p = 8

# Definir la función f(t) = 1/2 + sin(2t)
def modelo_posicion_final(tiempo_transcurrido):
    return posicion(tiempo_transcurrido) - p

def modelo_distancia(tiempo_transcurrido):
    return distancia(tiempo_transcurrido) - p

# Encontrar la raíz en el intervalo [0, 10]
root = brentq(modelo_posicion_final, 0, 10)


print(f"El tiempo necesario para alcanzar la posición {p} es:", np.round(root, 2), 'segundos')
# Out:
# El tiempo necesario para alcanzar la posición 8 es: 2.0 segundos

# %%
root = brentq(modelo_distancia, 0, 10)


print(f"El tiempo necesario para recorrer una distancia de {p} centímetros es:", np.round(root, 2), 'segundos')
# Out:
# El tiempo necesario para recorrer una distancia de 8 centímetros es: 1.33 segundos

# %% [markdown]
# **Conclusión:**
#
# * El **área con signo** determinada por la función velocidad es el desplazamiento
# * La suma de las áreas de las regiones determinadas por la función velocidad es la distancia recorrida.

# %%
# tabla de la función posición alcanzada

# %%
# tabla de la función distancia recorrida

# %% [markdown]
# # Ejemplo ilustrativo

# %% [markdown]
# # 10 ejercicios de entrenamiento o adquisición de habilidades obtenido a través de ChatGPT para una formación personalizada y centrada en la habilidad que se quiere lograr con la enseñanza del ejemplo anterior

# %%
# Tarea 1 de lectura de ejemplos y completación de procedimientos
# asignación de tarea para realizar antes de clase
# Consiste en leer y completar un ejemplo de texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_5.1'
numero_ejemplos_de_la_seccion = 54
numero_de_ejemplos_asignados = 3


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
examples = list(range(1, numero_ejemplos_de_la_seccion))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(examples, numero_de_ejemplos_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejemplos_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 1 de lectura de ejemplos y completación de procedimientos: 
     Si faltan los enunciados de los problemas, no se valora la tarea
      Si faltan de la conclusión verbales, no se valora la tarea 
      """, assignment_csv)
assignment_df
# Out:
# Tarea 1 de lectura de ejemplos y completación de procedimientos:
#      Si faltan los enunciados de los problemas, no se valora la tarea
#       Si faltan de la conclusión verbales, no se valora la tarea
#        tarea_Purcell_Página_202_Sección_3.8.csv
#                               Student  Example1  Example2  Example3
# 0   AMARIS FERNANDEZ SEBASTIAN CAMILO        48        22         2
# 1       ARENAS HERAZO GABRIEL ENRIQUE        37        18        20
# 2        AYALA MENDOZA MARISOL YACIRA        29        47        49
# 3          BERTEL RODELO MICHELL SMIT        45        35         7
# 4            BULA VERGARA MARIA PAULA        41        14        29
# 5             CANTILLO ENSUCHO DANIEL        22        46         5
# 6            CERVANTES DURAN ANGELICA        19        50        46
# 7             GUERRA NORIEGA YONATHAN        16        20        13
# 8     HINCAPIE CASTRO JOHAN SEBASTIAN        36        11        49
# ...

# %% [markdown]
# # Componente de manejo de calculadora Casio asociado al objetivo de aprendizaje de esta clase
#
# ## Pasos para lograr el objetivo de aprendizaje con la experimentación en la calculadora casio 570

# %% [markdown]
# # Tareas para realizar en clase

# %%
# Tarea 2 de solución de problemas 
# asignación de ejercicios de un seccion del texto guía

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 2 de solución de problemas:
      Si faltan los enunciados de los problemas, no se valora la tarea
      Si faltan de la conclusión verbales, no se valora la tarea 
        """, assignment_csv)
assignment_df
# Out:
# Tarea 2 de solución de problemas:
#        tarea_Purcell_Página_202_Sección_3.8.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     47      2     52     29     21
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     42     23     44     20      2
# 2       ARENAS HERAZO GABRIEL ENRIQUE     45     26     20     10     35
# 3        AYALA MENDOZA MARISOL YACIRA     24     18     39     54      5
# 4          BERTEL RODELO MICHELL SMIT      9     23     32     46     18
# 5            BULA VERGARA MARIA PAULA     34      5     44     43     21
# 6             CANTILLO ENSUCHO DANIEL      2     20     43      7     32
# 7            CERVANTES DURAN ANGELICA     46     39     20     19     36
# 8         GALLEGO TEJADA JUAN ESTEBAN     19      7      6     34     30
# 9             GUERRA NORIEGA YONATHAN     54     46      2     35      9
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN     47     53     42     46      4
# ...

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - escucha reiterada de grabaciones de formulas y resultados científicos.
#   - relectura de notas.
#   - ejercicios de mayor complejidad.
#
#
# ### No olvide asignar las tareas a los estudiantes a través de Google Colab y compartiendole el cuaderno de asignación a su correo institucional con fecha de entrega. [Google Colab](https://colab.research.google.com/?hl=es)

# %% [markdown]
# ## Asignación individual de tareas semanales

# %%
# Tarea 3 de solución de problemas describiendo procedimientos y justificándolos

# asignación de ejercicios de un seccion del texto guía

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 3 Solución problemas describiendo y justificando verbalmente: 
      Si faltan los enunciados de los problemas, no se valora la tarea
      Si faltan de la conclusión verbales, no se valora la tarea """, assignment_csv)
assignment_df
# Out:
# Tarea 3 Solución problemas describiendo y justificando:  tarea_Purcell_Página_202_Sección_3.8.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     39     17     21      4      9
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO      2     28     32      5     17
# 2       ARENAS HERAZO GABRIEL ENRIQUE     37     10     39     51     47
# 3        AYALA MENDOZA MARISOL YACIRA      4     20     40     26     47
# 4          BERTEL RODELO MICHELL SMIT     12     13     48     30     29
# 5            BULA VERGARA MARIA PAULA     51      4     15     46      2
# 6             CANTILLO ENSUCHO DANIEL      5     52     24     34     19
# 7            CERVANTES DURAN ANGELICA     49     20     48     53     26
# 8         GALLEGO TEJADA JUAN ESTEBAN     28     17     29     32     27
# 9             GUERRA NORIEGA YONATHAN     33     41     49     19      3
# ...

# %% [markdown]
# # No olvide la tarea de realizar la foda para autoevaluarse
#
# Fortalezas: F
# Oportuniudades O:
# Debilidades: D:
# Amenazas: A:

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Cálculo Vectorial
# * Martes 8-12 M: Fundamentos de Aritmética.
# * Miércoles 8 a 12 M: Fundamentos de la Lógica
# * Jueves 2 a 6PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Desarrollo del pensamiento matemático en la infancia.

# %% [markdown]
# # Horarios de monitoría y asesoría

# %% [markdown]
# ## Monitor Manuel

# %% [markdown]
# Martes y jueves de 8 - 12
# Miércoles 10 - 12 y de 2 a 4 PM
# Sábado: 8 - 12

# %% [markdown]
# ## Monitoría virtual
#
# Telefono del monitos en whatsApp: 3043936088
#
# Juan David Cano Castrillón
# Estudiante de Pregrado.
# juan.canoc1@udea.edu.co
# 3043936088

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://github.com/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/grajales_lina_matemticas.pdf)
#
# * Duval, R. (2004). Semiosis y pensamiento humano: registros semióticos y aprendizajes intelectuales. Universidad del Valle.
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](https://github.com/marco-canas/fundamentos_logica/blob/main/referentes/2_uzcategui/uscategui.pdf)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/chollet/Fran%C3%A7ois%20Chollet%20-%20Deep%20Learning%20with%20Python-Manning%20(2018).pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/geron/Hands-On%20Machine%20Learning-3nd_Edition(2022).pdf)
#
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/mckinney/Wes_McKinney.pdf)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# # Aportes de mis estudiantes a la metodología del curso
# 1.
#
# Sus opiniones y aportes son muy importantes para mi. Pues esta es una investigación educativa y un servicio de enseñanza para ustedes. Ustedes son la razón de ser de mi actividad docente. Dios los bendiga.

# %% [markdown]
# # Aportes de mis colegas docentes a la metodología que estoy aplicando en mis cursos.

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado.
#
# Y a mi esposa Yasmira por su apoyo, orientación y acompañamiento.
