# %% [markdown]
# # Ejercicio 1 sobre Taller de lógica y conjuntos
# 1. Escriba de manera simbólica los siguientes enunciados:
#  * Si las exportaciones disminuyen, entonces bajarán las utilidades.
#  $P Rightarrow
