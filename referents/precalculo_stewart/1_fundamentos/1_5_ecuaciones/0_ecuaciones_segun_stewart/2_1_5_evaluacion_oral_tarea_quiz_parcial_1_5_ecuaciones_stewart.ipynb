# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/calculo/blob/main/referents/precalculo_stewart/1_fundamentos/1_5_ecuaciones/0_ecuaciones_segun_stewart/2_1_5_evaluacion_oral_tarea_quiz_parcial_1_5_ecuaciones_stewart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=yVUD_CXr7_Y)

# %% [markdown]
# ## [Vínculo al programa del curso:](https://github.com/marco-canas/seminario_didactica_aritmetica/blob/main/plan%20del%20curso_seminario_didactica_aritmetica.docx)

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# Reconociento de sus aportes a este saber pedagógico para la enseñanza de el concepto de ecuación en el campo de los números reales.
#
# ![En la nariguera](https://github.com/marco-canas/fundamentos_de_las_matematicas/blob/main/images/photos/estudiantes_lic_math_2023-08-01.jpeg?raw=true)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria, licenciatura en Matemáticas, licenciatura en educación infantil y administración de empresas.
#
# [Confiar e inspirar de Stephen Covey](https://github.com/marco-canas/confiar_e_inspirar/blob/main/primera_parte_el_futuro_del_liderazgo_de_mandar_y_controlar_confiar_e_inspirar/1_el_mundo_ha_cambiado_nuestro_estilo_de_liderazgo_no/1_el_mundo_ha_cambiado_nuestro_estilo_de_liderazgo_no.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación de Tareas en cuadernos Jupyter, Quiz, Parcial, oral.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Diferenciar los conceptos de ecuación lineal $ax + b = 0$ y función lineal $y = ax + b$.
# * Diferenciar los conceptos de ecuación cuadrática y de función cuadrática.
# * Utilizar el concepto de ecuación lineal en la solución de problemas reales.
# * que el estudiante pueda experimentar modelando ayudado por sympy, en especial su función `solve()`.
# * Aprender a editar ecuaciones en lenguaje latex, lo que le ayude a desarrollar habilidades de comunicación científica.
# * Capacidad de justificar de manera escrita.
# * Capacidad para interpretar y analizar ecuaciones.
# * Capacidad para describir procesos de manera oral.
# * Capacidad de identificar los coeficientes de una ecuación lineal o cuadrática.
# * Evaluar la capacidad de hacerse entender de manera oral.

# %% [markdown]
# # Llamada aleatoria para los estudiantes a participar para ser evaluados de manera oral

# %%
import pandas as pd
import random

# Cargar la lista de estudiantes desde la URL
url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/seminario_didactica_aritmetica.csv'
estudiantes = pd.read_csv(url)

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def llamar_estudiante():
    estudiante_aleatorio = random.choice(estudiantes['Nombre'])
    print(f"Llamando a {estudiante_aleatorio}...")
    
    
# Llamar a la función para realizar el proceso
llamar_estudiante()
# Out:
# Llamando a RODRIGUEZ VERONA CARLOS MARIO...

# %% [markdown]
# # Tarea o taller para evaluar: Componente de evaluación del trabajo independiente del estudiante

# %%
# Tarea para antes de realizada la clase
# Consiste en la lectura y completación de un ejemplo del texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'seminario_didactica_aritmetica'
nombre_texto_guia = 'Precálculo:Matemáticas para el cálculo_stewart_séptima_edición'
pagina_y_seccion = 'Página_55_Sección_1.5'
numero_ejercicios_taller = 14
numero_de_ejercicios_asignados = 3


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
print('Debe transcribir el ejemplo \n en su cuaderno manuscrito y Jupyter y completar los procedimientos')
assignment_df
# Out:
# Tarea asignada:  tarea_Precálculo:Matemáticas para el cálculo_stewart_séptima_edición_Página_55_Sección_1.5.csv
# Debe transcribir el ejemplo
#  en su cuaderno manuscrito y Jupyter y completar los procedimientos
#                               Student  Example1  Example2  Example3
# 0                 ARIAS ARRIETA FREDY         9        11         4
# 1       BOHORQUEZ NAVARRO DINA ESTELA         6         3         5
# 2        CARDONA RAMIREZ SARA PAULINA         5        10         4
# 3             CASTANEDA REINOZA DIEGO         6         7        11
# 4             ESPEJO PEREZ LUIS DAVID         4         2        12
# 5   HERNANDEZ GUERRA FABIAN ALEJANDRO         7         8        11
# 6        LUCAS FLOREZ NAYELIS NATALIA         4         9        12
# 7    MARTINEZ BALLESTEROS VICTOR HUGO         3         7        14
# 8        MARTINEZ MENDOZA JAIR MIGUEL         2        14        10
# 9           OCHOA ARRIETA JUAN ANDRES         2         9        13
# ...

# %%
# Tarea: Asignación de ejercicio para realizar en clase


import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Precálculo:Matemáticas para el cálculo_Stewart_séptima_edición'
pagina_y_seccion = 'Página_55_Sección_1.5'
numero_ejercicios_taller = 141
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
assignment_df
# Out:
# Tarea asignada:  tarea_Precálculo:Matemáticas para el cálculo_Stewart_séptima_edición_Página_55_Sección_1.5.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0        AGUDELO MORENO RENATO DIRNEY     16     56     32    127     12
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     74     33     23     43     86
# 2       ARENAS HERAZO GABRIEL ENRIQUE     75     79     61    108     53
# 3        AYALA MENDOZA MARISOL YACIRA     44     50     55     42    123
# 4          BERTEL RODELO MICHELL SMIT     16     28     79      2    141
# 5            BULA VERGARA MARIA PAULA     82    107     69     99     42
# 6             CANTILLO ENSUCHO DANIEL     37     55     12     83    110
# 7            CERVANTES DURAN ANGELICA     23     24    103     59     22
# 8         GALLEGO TEJADA JUAN ESTEBAN    108    106    110     11     18
# 9             GUERRA NORIEGA YONATHAN     67    139    113    137     98
# ...

# %%
# Tarea para después de la clase: asignación de ejercicios de un seccion del texto guía

# Tarea para adquisición de habilidades de justificación de manera escrita (Afirmación - razón)


import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'seminario_didactica_aritmetica'
nombre_texto_guia = 'Precálculo:Matemáticas para el cálculo_stewart_séptima_edición'
pagina_y_seccion = 'Página_55_Sección_1.5'
numero_ejercicios_taller = 141
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
assignment_df
# Out:
# Tarea asignada:  tarea_Precálculo:Matemáticas para el cálculo_stewart_séptima_edición_Página_55_Sección_1.5.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0                 ARIAS ARRIETA FREDY     41    106     80     36     48
# 1       BOHORQUEZ NAVARRO DINA ESTELA     74     80     71     89    107
# 2        CARDONA RAMIREZ SARA PAULINA    140     77     71     47     72
# 3             CASTANEDA REINOZA DIEGO    103      4     85    116     97
# 4             ESPEJO PEREZ LUIS DAVID     27     24     71     42     52
# 5   HERNANDEZ GUERRA FABIAN ALEJANDRO      6     16     74     51     15
# 6        LUCAS FLOREZ NAYELIS NATALIA     36    120     87     29     84
# 7    MARTINEZ BALLESTEROS VICTOR HUGO    127     95    102     88    138
# 8        MARTINEZ MENDOZA JAIR MIGUEL     20    117     27     29    109
# 9           OCHOA ARRIETA JUAN ANDRES     65    123     59    127     11
# ...

# %% [markdown]
# # Ejemplo de quiz

# %%
# asignación de tres ejercicio del taller para quiz

import pandas as pd
import numpy as np
import random
import requests

# Descargar la lista de estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/seminario_didactica_aritmetica.csv"
exercises = list(range(1, 84))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, 3)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exercise 1", "Exercise 2", "Exercise 3"]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_seccion_01_purcell.csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df
# Out:
# Asignaciones guardadas en tarea_seccion_01_purcell.csv
#                               Student  Exercise 1  Exercise 2  Exercise 3
# 0                 ARIAS ARRIETA FREDY           2           7          39
# 1       BOHORQUEZ NAVARRO DINA ESTELA          28          56          27
# 2        CARDONA RAMIREZ SARA PAULINA          30          54          74
# 3             CASTANEDA REINOZA DIEGO          41          13          23
# 4             ESPEJO PEREZ LUIS DAVID          57           4          55
# 5   HERNANDEZ GUERRA FABIAN ALEJANDRO          44          49          37
# 6        LUCAS FLOREZ NAYELIS NATALIA           8          73          64
# 7    MARTINEZ BALLESTEROS VICTOR HUGO          80          22          44
# 8        MARTINEZ MENDOZA JAIR MIGUEL           5          36          12
# 9           OCHOA ARRIETA JUAN ANDRES          37          30           4
# 10      RODRIGUEZ VERONA CARLOS MARIO          34          12           4
# ...

# %% [markdown]
# # Otros ejercicios de tarea y entrenamiento
#
#
# ¡Claro! Aquí tienes diez ecuaciones lineales de la forma $ax + b = 0$ con soluciones enteras:
#
# 1. $2x + 3 = 0$
# 2. $-5x + 8 = 0$
# 3. $4x - 6 = 0$
# 4. $7x + 2 = 0$
# 5. $-3x - 9 = 0$
# 6. $6x + 12 = 0$
# 7. $-8x - 4 = 0$
# 8. $9x - 27 = 0$
# 9. $-2x + 5 = 0$
# 10. $3x - 15 = 0$
#
# Espero que estas ecuaciones sean útiles para tus estudiantes.

# %% [markdown]
# # Quiz

# %%
import numpy as np 

np.random.seed(424)  

np.random.choice(141) + 1
# Out:
# 17

# %% [markdown]
# # Ejemplo de parcial

# %%
import numpy as np 

np.random.seed(1213)  

np.random.choice(141) + 1
# Out:
# 12

# %% [markdown]
# # Evaluación oral
#
# * Diga los seis métodos que hemos visto para resolver ecuaciones lineales, cuadráticas y con radicales.
#
#
#
# ### Respuesta:
# 1. Observacion o inspección. (Leer una ecuación como una pregunta acerca de un número desconocido y su comportamiento)
# 2. Transposición de términos y factores.
# 2. Propiedades de uniformidad de igualdades
# 3. Propiedad del producto cero.
# 4. Método de factorización y aplicación de la propiedad del producto cero.
# 5. Aplicación de la formula del bachiller
# 6. Cambio de variable.
#
# * ¿Cuándo es aplicable la transposición de términos?

# %% [markdown]
# # Rúbrica de evaluación de asistencia a la conferencia: NeuroMatemática
#
# 1. ¿Cómo describe el autor el funcionamiento de nuestro cerebro humano?
# 2. ¿Cómo se modela o representa el funcionamiento del cerebro humano desde la matemática?
# 3. ¿Qué funciones matemáticas se utilizan en neuromatemáticas?

# %% [markdown]
# # Programa para evaluación del seguimiento mensual de los estudiantes

# %%
# Programa para valoración cuantitativa por meses para los estudiantes de todos los cursos
import numpy as np 
import pandas as pd   

#weights
weightAssistance = 12/100
weightAttentionParticipation = 8/100
weightHandwrittenNotebook = 8/100
weightJupyterNotebook = 20/100
weightQuiz = 16/100
weightPartial = 48/100

url_group = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/seminario_didactica_aritmetica.csv'

df = pd.read_csv(url_group, decimal = ',') 

df.Assistance = (df.Assistance/np.max(df.Assistance))*5.0
df.AttentionParticipation = (df.AttentionParticipation/np.max(df.AttentionParticipation))*5.0
df.HandwrittenNotebook = (df.HandwrittenNotebook/np.max(df.HandwrittenNotebook))*5.0
df.JupyterNotebook = (df.JupyterNotebook/np.max(df.JupyterNotebook))*5.0  


df['FollowUp'] = df.Assistance*weightAssistance + \
                 df.AttentionParticipation*weightAttentionParticipation + \
                 df.HandwrittenNotebook*weightHandwrittenNotebook+\
                 df.JupyterNotebook*weightJupyterNotebook+\
                 df.Quiz*weightQuiz + \
                 df.Partial*weightPartial

df.FollowUp = df.FollowUp.round(1)

df[['Nombre', 'FollowUp']]
# Out:
#                                Nombre                            Email  \
# 0        AGUDELO MORENO RENATO DIRNEY       renato.agudelo@udea.edu.co
# 1   AMARIS FERNANDEZ SEBASTIAN CAMILO     sebastian.amaris@udea.edu.co
# 2       ARENAS HERAZO GABRIEL ENRIQUE       gabriel.arenas@udea.edu.co
# 3        AYALA MENDOZA MARISOL YACIRA        marisol.ayala@udea.edu.co
# 4          BERTEL RODELO MICHELL SMIT       michell.bertel@udea.edu.co
# 5            BULA VERGARA MARIA PAULA           paula.bula@udea.edu.co
# 6             CANTILLO ENSUCHO DANIEL      daniel.cantillo@udea.edu.co
# 7            CERVANTES DURAN ANGELICA   angelica.cervantes@udea.edu.co
# 8         GALLEGO TEJADA JUAN ESTEBAN  juanesteban.gallego@udea.edu.co
# 9             GUERRA NORIEGA YONATHAN      yonathan.guerra@udea.edu.co
# 10    HINCAPIE CASTRO JOHAN SEBASTIAN       johan.hincapie@udea.edu.co
# 11             HUMANEZ SANCHEZ CAMILO       camilo.humanez@udea.edu.co
# ...

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Cuestionario para realizar labores de memorización y observación,  a la síntesis de la información

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar en el drive asociuado al correo institucional de la Universidad Nacional del Profesor Marso para albergar los archivosd de audio de fomento a la memoirización, enunciación y parafraseo de los resultados científicos, prtopiedades, reglas, etc.
#
# * Vocaroo

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# # Vocabulary

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
