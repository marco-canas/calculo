# %% [markdown]
# # Metodología de enseñanza y aprendizaje activo

# %% [markdown]
# # Función de python que le ingresa $y = f(x)$ y el intervalo $[a,b]$ y que devuelve el gráfico del área bajo la curva.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función lambda
f = lambda x: x**2  # Cambia esto por tu función

def graficar_area_bajo_curva(funcion, intervalo ):
    """
    INPUT: 
    OUTPUT: 
    """

# Definir los límites del intervalo cerrado
a = -1  # Límite inferior
b = 2   # Límite superior

# Generar puntos para graficar la función y las líneas verticales
x_vals = np.linspace(a, b, 400)
y_vals = f(x_vals)
x_a = np.array([a, a])
y_a = np.array([0, f(a)])
x_b = np.array([b, b])
y_b = np.array([0, f(b)])

# Graficar la función y las líneas verticales
plt.plot(x_vals, y_vals, label='y = f(x)')
plt.plot(x_a, y_a, 'r--', label=f'x = {a}')
plt.plot(x_b, y_b, 'g--', label=f'x = {b}')
plt.fill_between(x_vals, y_vals, alpha=0.2)

# Etiquetas y leyenda
plt.xlabel('x')
plt.ylabel('y')
plt.title('Región de Integración')
plt.legend()

# Mostrar el gráfico
plt.grid()
plt.show()
